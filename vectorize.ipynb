# %%
import collections
import warnings
import ScraperFC as sfc  # LEAVE THIS!
import numpy as np
import pandas as pd
from scipy.optimize import minimize
from scipy.stats import poisson

# %%
def calculate_rps(probs, outcome):
    """
    Calculate the Ranked Probability Score

    Parameters
    ----------
    probs : list
        A list of the predicted probabilities of each outcome occurring

    outcome : int
        An integer designating which index in `probs` was the observed outcome

    Returns
    -------
    float
        The Ranked Probability Score as floating point number
    """
    cum_probs = np.cumsum(probs)
    cum_outcomes = np.zeros(len(probs))
    cum_outcomes[outcome] = 1
    cum_outcomes = np.cumsum(cum_outcomes)

    sum_rps = 0
    for i in range(len(probs)):
        sum_rps += (cum_probs[i] - cum_outcomes[i]) ** 2

    return sum_rps / (len(probs) - 1)

# %%
def rho_correction_vec(df):
    dc_adj = np.select(
        [
            (df["goals_home"] == 0) & (df["goals_away"] == 0),
            (df["goals_home"] == 0) & (df["goals_away"] == 1),
            (df["goals_home"] == 1) & (df["goals_away"] == 0),
            (df["goals_home"] == 1) & (df["goals_away"] == 1),
        ],
        [
            1 - (df["home_exp"] * df["away_exp"] * df["rho"]),
            1 + (df["home_exp"] * df["rho"]),
            1 + (df["away_exp"] * df["rho"]),
            1 - df["rho"],
        ],
        default=1,
    )
    return dc_adj

# %%
def dc_decay(xi, t):
    return np.exp(-xi * t)

# %%
class FootballProbabilityGrid(list):
    def __init__(
        self,
        goal_matrix: list,
        home_goal_expectation: float,
        away_goal_expectation: float,
    ):
        list.__init__(self, goal_matrix)
        self.home_goal_expectation = home_goal_expectation
        self.away_goal_expectation = away_goal_expectation

        # Compute marginal probabilities for home and away shots on target
        self.home_sot_probabilities = np.sum(self, axis=1)
        self.away_sot_probabilities = np.sum(self, axis=0)


    def __repr__(self):
        repr_str = ""
        repr_str += "Module: Penaltyblog"
        repr_str += "\n"
        repr_str += "\n"

        repr_str += "Class: FootballProbabilityGrid"
        repr_str += "\n"
        repr_str += "\n"

        repr_str += "Home Goal Expectation: {0}".format(self.home_goal_expectation)
        repr_str += "\n"
        repr_str += "Away Goal Expectation: {0}".format(self.away_goal_expectation)
        repr_str += "\n"
        repr_str += "\n"

        repr_str += "Home Win: {0}".format(self.home_win)
        repr_str += "\n"
        repr_str += "Draw: {0}".format(self.draw)
        repr_str += "\n"
        repr_str += "Away Win: {0}".format(self.away_win)
        repr_str += "\n"

        repr_str += "BTTS: {0}".format(self.both_teams_to_score)
        repr_str += "\n"
        return repr_str

    def __str__(self):
        return self.__repr__()

    def _sum(self, func):
        return sum(
            [
                self[a][b]
                for a in range(len(self))
                for b in range(len(self))
                if func(a, b)
            ]
        )

    @property
    def home_win(self) -> float:
        """
        Probability of home win

        Returns
        ------
        float
            Probability of home win
        """
        return self._sum(lambda a, b: a > b)

    @property
    def draw(self) -> float:
        """
        Probability of draw

        Returns
        ------
        float
            Probability of draw
        """
        return self._sum(lambda a, b: a == b)

    @property
    def away_win(self) -> float:
        """
        Probability of away win

        Returns
        ------
        float
            Probability of away win
        """
        return self._sum(lambda a, b: a < b)

    @property
    def both_teams_to_score(self) -> float:
        """
        Probability of both teams scoring

        Returns
        ------
        float
            Probability of both teams scoring
        """
        return self._sum(lambda a, b: a > 0 and b > 0)

    @property
    def home_draw_away(self) -> list:
        """
        1x2 Probabilities

        Returns
        ------
        list
            Probability of home win
        """
        return [self.home_win, self.draw, self.away_win]

    def total_goals(self, over_under: str, strike: float) -> float:
        """
        Predicts the probabilities of `total goals` market

        Parameters
        ----------
        over_under : str
            Whether probabilities are for over / under the
            total goals value - must be one of ['over', 'under']

        strike : float
            The total goals value for the market

        Returns
        ------
        float
            Probability of over / under the strike occurring
        """
        if over_under == "over":
            func = lambda a, b: a + b > strike
        elif over_under == "under":
            func = lambda a, b: a + b < strike
        else:
            raise ValueError("over_under must be one of ['over', 'under']")
        return self._sum(func)

    def asian_handicap(self, home_away: str, strike: float) -> float:
        """
        Predicts the probabilities of `asian handicap` market

        Parameters
        ----------
        home_away : str
            Whether probabilities are for home / away team -
            must be one of ['home', 'away']

        goals : float
            The total goals value

        Returns
        ------
        float
            Probability of home / away team outscoring the strike
        """
        if home_away == "home":
            func = lambda a, b: a - b > strike
        elif home_away == "away":
            func = lambda a, b: b - a > strike
        else:
            raise ValueError("home_away must be one of ['home', 'away']")
        return self._sum(func)

# %%
class DixonColesGoalModel:
    """Dixon and Coles adjusted Poisson model for predicting outcomes of football
    (soccer) matches

    Methods
    -------
    fit()
        fits a Dixon and Coles adjusted Poisson model to the data to calculate the team strengths.
        Must be called before the model can be used to predict game outcomes

    predict(home_team, away_team, max_goals=15)
        predict the outcome of a football (soccer) game between the home_team and away_team

    get_params()
        Returns the fitted parameters from the model
    """

    def __init__(self, goals_home, goals_away, teams_home, teams_away, weights=1):
        """
        Parameters
        ----------
        goals_home : list
            A list or pd.Series of goals scored by the home_team
        goals_away : list
            A list or pd.Series of goals scored by the away_team
        teams_home : list
            A list or pd.Series of team_names for the home_team
        teams_away : list
            A list or pd.Series of team_names for the away_team
        weights : list
            A list or pd.Series of weights for the data,
            the lower the weight the less the match has on the output
        """

        self.fixtures = pd.DataFrame([goals_home, goals_away, teams_home, teams_away]).T
        self.fixtures.columns = ["goals_home", "goals_away", "team_home", "team_away"]
        self.fixtures["goals_home"] = self.fixtures["goals_home"].astype(int)
        self.fixtures["goals_away"] = self.fixtures["goals_away"].astype(int)
        self.fixtures["weights"] = weights

        self.teams = np.sort(np.unique(np.concatenate([teams_home, teams_away])))
        self.n_teams = len(self.teams)

        self._params = np.concatenate(
            (
                [1] * self.n_teams,
                [-1] * self.n_teams,
                [0.25],  # home advantage
                [-0.1],  # rho
            )
        )

        self._res = None
        self.loglikelihood = None
        self.aic = None
        self.n_params = None
        self.fitted = False

    def __repr__(self):
        repr_str = ""
        repr_str += "Module: Penaltyblog"
        repr_str += "\n"
        repr_str += "\n"

        repr_str += "Model: Dixon and Coles"
        repr_str += "\n"
        repr_str += "\n"

        if not self.fitted:
            repr_str += "Status: Model not fitted"
            return repr_str

        repr_str += "Number of parameters: {0}".format(self.n_params)
        repr_str += "\n"
        repr_str += "Log Likelihood: {0}".format(round(self.loglikelihood, 3))
        repr_str += "\n"
        repr_str += "AIC: {0}".format(round(self.aic, 3))
        repr_str += "\n"
        repr_str += "\n"

        repr_str += "{0: <20} {1:<20} {2:<20}".format("Team", "Attack", "Defence")
        repr_str += "\n"
        repr_str += "-" * 60
        repr_str += "\n"

        for idx, team in enumerate(self.teams):
            repr_str += "{0: <20} {1:<20} {2:<20}".format(
                self.teams[idx],
                round(self._params[idx], 3),
                round(self._params[idx + self.n_teams], 3),
            )
            repr_str += "\n"

        repr_str += "-" * 60
        repr_str += "\n"

        repr_str += "Home Advantage: {0}".format(round(self._params[-2], 3))
        repr_str += "\n"
        repr_str += "Rho: {0}".format(round(self._params[-1], 3))
        repr_str += "\n"

        return repr_str

    def __str__(self):
        return self.__repr__()

    @staticmethod
    def _fit(params, fixtures, teams):
        """
        Internal method, not to called directly by the user
        """
        n_teams = len(teams)

        params_df = (
            pd.DataFrame(params[:n_teams], columns=["attack"])
            .assign(defence=params[n_teams : n_teams * 2])
            .assign(team=teams)
        )

        df2 = (
            fixtures.merge(params_df, left_on="team_home", right_on="team")
            .rename(columns={"attack": "home_attack", "defence": "home_defence"})
            .drop("team", axis=1)
            .merge(params_df, left_on="team_away", right_on="team")
            .rename(columns={"attack": "away_attack", "defence": "away_defence"})
            .assign(hfa=params[-2])
            .assign(rho=params[-1])
        )

        df2["home_exp"] = np.exp(df2["hfa"] + df2["home_attack"] + df2["away_defence"])
        df2["away_exp"] = np.exp(df2["away_attack"] + df2["home_defence"])
        df2["home_llk"] = poisson.logpmf(df2["goals_home"], df2["home_exp"])
        df2["away_llk"] = poisson.logpmf(df2["goals_away"], df2["away_exp"])
        df2["dc_adj"] = rho_correction_vec(df2)

        df2["llk"] = (df2["home_llk"] + df2["away_llk"] + np.log(df2["dc_adj"])) * df2[
            "weights"
        ]

        return -df2["llk"].sum()

    def fit(self):
        """
        Fits the model to the data and calculates the team strengths,
        home advantage and intercept. Should be called before `predict` can be used
        """
        options = {
            "maxiter": 100,
            "disp": False,
        }

        constraints = [
            {
                "type": "eq",
                "fun": lambda x: sum(x[: self.n_teams]) - self.n_teams,
            }
        ]

        bounds = [(-3, 3)] * self.n_teams
        bounds += [(-3, 3)] * self.n_teams
        bounds += [(0, 2)]
        bounds += [(-2, 2)]

        with warnings.catch_warnings():
            warnings.filterwarnings("ignore")
            self._res = minimize(
                self._fit,
                self._params,
                args=(self.fixtures, self.teams),
                constraints=constraints,
                bounds=bounds,
                options=options,
            )

        self._params = self._res["x"]
        self.n_params = len(self._params)
        self.loglikelihood = self._res["fun"] * -1
        self.aic = -2 * (self.loglikelihood) + 2 * self.n_params
        self.fitted = True

    def predict(self, home_team, away_team, max_goals=15):
        """
        Predicts the probabilities of the different possible match outcomes

        Parameters
        ----------
        home_team : str
            The name of the home_team, must have been in the data the model was fitted on

        away_team : str
            The name of the away_team, must have been in the data the model was fitted on

        max_goals : int
            The maximum number of goals to calculate the probabilities over.
            Reducing this will improve performance slightly at the expensive of acuuracy

        Returns
        -------
        FootballProbabilityGrid
            A class providing access to a range of probabilites,
            such as 1x2, asian handicaps, over unders etc
        """
        # check the model has been fit
        if not self.fitted:
            raise ValueError(
                (
                    "Model's parameters have not been fit yet, please call the `fit()` "
                    "function before making any predictions"
                )
            )

        if isinstance(home_team, str) and isinstance(away_team, str):
            return self._predict(home_team, away_team, max_goals)

        elif isinstance(home_team, collections.abc.Sequence) and isinstance(
            away_team, collections.abc.Sequence
        ):
            results = [
                self._predict(x[0], x[1], max_goals) for x in zip(home_team, away_team)
            ]
            return results

        else:
            raise ValueError("Team data types not recognised")

    def _predict(self, home_team, away_team, max_goals=15):
        """
        Predicts the probabilities of the different possible match outcomes

        Parameters
        ----------
        home_team : str
            The name of the home_team, must have been in the data the model was fitted on

        away_team : str
            The name of the away_team, must have been in the data the model was fitted on

        max_goals : int
            The maximum number of goals to calculate the probabilities over.
            Reducing this will improve performance slightly at the expensive of acuuracy

        Returns
        -------
        FootballProbabilityGrid
            A class providing access to a range of probabilites,
            such as 1x2, asian handicaps, over unders etc
        """

        # check we have parameters for teams
        if home_team not in self.teams:
            raise ValueError(
                (
                    "No parameters for home team - "
                    "please ensure the team was included in the training data"
                )
            )

        if away_team not in self.teams:
            raise ValueError(
                (
                    "No parameters for away team - "
                    "please ensure the team was included in the training data"
                )
            )

        # get the relevant model parameters
        home_idx = np.where(self.teams == home_team)[0][0]
        away_idx = np.where(self.teams == away_team)[0][0]

        home_attack = self._params[home_idx]
        away_attack = self._params[away_idx]

        home_defence = self._params[home_idx + self.n_teams]
        away_defence = self._params[away_idx + self.n_teams]

        home_advantage = self._params[-2]
        rho = self._params[-1]

        # calculate the goal expectation
        home_goals = np.exp(home_advantage + home_attack + away_defence)
        away_goals = np.exp(away_attack + home_defence)
        home_goals_vector = poisson(home_goals).pmf(np.arange(0, max_goals))
        away_goals_vector = poisson(away_goals).pmf(np.arange(0, max_goals))

        # get the probabilities for each possible score
        m = np.outer(home_goals_vector, away_goals_vector)

        # apply Dixon and Coles adjustment
        m[0, 0] *= 1 - home_goals * away_goals * rho
        m[0, 1] *= 1 + home_goals * rho
        m[1, 0] *= 1 + away_goals * rho
        m[1, 1] *= 1 - rho

        # and return the FootballProbabilityGrid
        probability_grid = FootballProbabilityGrid(m, home_goals, away_goals)

        return probability_grid

    def get_params(self):
        """
        Provides access to the model's fitted parameters

        Returns
        -------
        dict
            A dict containing the model's parameters
        """
        if not self.fitted:
            raise ValueError(
                "Model's parameters have not been fit yet, please call the `fit()` function first"
            )

        params = dict(
            zip(
                ["attack_" + team for team in self.teams]
                + ["defence_" + team for team in self.teams]
                + ["home_advantage", "rho"],
                self._res["x"],
            )
        )
        return params

# %%
class DixonColesGoalModel_sot:
    """Dixon and Coles adjusted Poisson model for predicting outcomes of football
    (soccer) matches

    Methods
    -------
    fit()
        fits a Dixon and Coles adjusted Poisson model to the data to calculate the team strengths.
        Must be called before the model can be used to predict game outcomes

    predict(home_team, away_team, max_goals=15)
        predict the outcome of a football (soccer) game between the home_team and away_team

    get_params()
        Returns the fitted parameters from the model

    fit_shots_on_target()
        Fits the model for shots on target using the provided data

    predict_shots_on_target(home_team, away_team, max_shots=15)
        Predicts the shots on target between the home_team and away_team
    """

    def __init__(
        self,
        goals_home,
        goals_away,
        teams_home,
        teams_away,
        shots_on_target_home=None,
        shots_on_target_away=None,
        weights=1,
    ):
        """
        Parameters
        ----------
        goals_home : list
            A list or pd.Series of goals scored by the home_team
        goals_away : list
            A list or pd.Series of goals scored by the away_team
        teams_home : list
            A list or pd.Series of team_names for the home_team
        teams_away : list
            A list or pd.Series of team_names for the away_team
        shots_on_target_home : list, optional
            A list or pd.Series of shots on target by the home_team
        shots_on_target_away : list, optional
            A list or pd.Series of shots on target by the away_team
        weights : list
            A list or pd.Series of weights for the data,
            the lower the weight the less the match has on the output
        """

        self.fixtures = pd.DataFrame([goals_home, goals_away, teams_home, teams_away]).T
        self.fixtures.columns = ["goals_home", "goals_away", "team_home", "team_away"]
        self.fixtures["goals_home"] = self.fixtures["goals_home"].astype(int)
        self.fixtures["goals_away"] = self.fixtures["goals_away"].astype(int)
        self.fixtures["weights"] = weights

        if shots_on_target_home is not None and shots_on_target_away is not None:
            self.fixtures["shots_on_target_home"] = shots_on_target_home
            self.fixtures["shots_on_target_away"] = shots_on_target_away
        else:
            self.fixtures["shots_on_target_home"] = np.nan
            self.fixtures["shots_on_target_away"] = np.nan

        self.teams = np.sort(np.unique(np.concatenate([teams_home, teams_away])))
        self.n_teams = len(self.teams)

        self._params = np.concatenate(
            (
                [1] * self.n_teams,
                [-1] * self.n_teams,
                [0.25],  # home advantage
                [-0.1],  # rho
            )
        )

        self._res = None
        self.loglikelihood = None
        self.aic = None
        self.n_params = None
        self.fitted = False

        # Initialize variables for shots on target model
        self._params_sot = None
        self._res_sot = None
        self.loglikelihood_sot = None
        self.aic_sot = None
        self.n_params_sot = None
        self.fitted_sot = False

    # ... [existing methods: __repr__, __str__, _fit, fit, predict, _predict, get_params] ...

    def fit_shots_on_target(self):
        """
        Fits the model to the data for shots on target and calculates the team strengths,
        home advantage, and rho for shots on target.
        Should be called before `predict_shots_on_target` can be used.
        """
        if self.fixtures["shots_on_target_home"].isnull().any():
            raise ValueError(
                "Shots on target data is missing. Please provide shots on target data in the __init__ method."
            )

        # Initialize parameters for shots on target model
        self._params_sot = np.concatenate(
            (
                [1] * self.n_teams,   # attack parameters
                [-1] * self.n_teams,  # defence parameters
                [0.25],               # home advantage
                [-0.1],               # rho
            )
        )

        options = {
            "maxiter": 100,
            "disp": False,
        }

        constraints = [
            {
                "type": "eq",
                "fun": lambda x: sum(x[: self.n_teams]) - self.n_teams,
            }
        ]

        bounds = [(-3, 3)] * self.n_teams
        bounds += [(-3, 3)] * self.n_teams
        bounds += [(0, 2)]
        bounds += [(-2, 2)]

        with warnings.catch_warnings():
            warnings.filterwarnings("ignore")
            self._res_sot = minimize(
                self._fit_shots_on_target,
                self._params_sot,
                args=(self.fixtures, self.teams),
                constraints=constraints,
                bounds=bounds,
                options=options,
            )

        self._params_sot = self._res_sot["x"]
        self.n_params_sot = len(self._params_sot)
        self.loglikelihood_sot = self._res_sot["fun"] * -1
        self.aic_sot = -2 * (self.loglikelihood_sot) + 2 * self.n_params_sot
        self.fitted_sot = True

    def _fit_shots_on_target(self, params, fixtures, teams):
        """
        Internal method for fitting the shots on target model.
        Not to be called directly by the user.
        """
        n_teams = len(teams)

        params_df = (
            pd.DataFrame(params[:n_teams], columns=["attack"])
            .assign(defence=params[n_teams : n_teams * 2])
            .assign(team=teams)
        )

        df2 = (
            fixtures.merge(params_df, left_on="team_home", right_on="team")
            .rename(columns={"attack": "home_attack", "defence": "home_defence"})
            .drop("team", axis=1)
            .merge(params_df, left_on="team_away", right_on="team")
            .rename(columns={"attack": "away_attack", "defence": "away_defence"})
            .assign(hfa=params[-2])
            .assign(rho=params[-1])
        )

        df2["home_exp"] = np.exp(df2["hfa"] + df2["home_attack"] + df2["away_defence"])
        df2["away_exp"] = np.exp(df2["away_attack"] + df2["home_defence"])

        df2["home_llk"] = poisson.logpmf(df2["shots_on_target_home"], df2["home_exp"])
        df2["away_llk"] = poisson.logpmf(df2["shots_on_target_away"], df2["away_exp"])
        df2["dc_adj"] = rho_correction_vec(df2)

        df2["llk"] = (df2["home_llk"] + df2["away_llk"] + np.log(df2["dc_adj"])) * df2["weights"]

        return -df2["llk"].sum()

    def predict_shots_on_target(self, home_team, away_team, max_shots=15):
        """
        Predicts the probabilities of the different possible shots on target outcomes

        Parameters
        ----------
        home_team : str
            The name of the home_team, must have been in the data the model was fitted on

        away_team : str
            The name of the away_team, must have been in the data the model was fitted on

        max_shots : int
            The maximum number of shots on target to calculate the probabilities over.
            Reducing this will improve performance slightly at the expensive of accuracy

        Returns
        -------
        FootballProbabilityGrid
            A class providing access to a range of probabilities,
            such as over/unders for shots on target
        """
        # Check if the model has been fitted
        if not self.fitted_sot:
            raise ValueError(
                (
                    "Shots on target model's parameters have not been fit yet, "
                    "please call the `fit_shots_on_target()` function before making any predictions"
                )
            )

        if isinstance(home_team, str) and isinstance(away_team, str):
            return self._predict_shots_on_target(home_team, away_team, max_shots)

        elif isinstance(home_team, collections.abc.Sequence) and isinstance(
            away_team, collections.abc.Sequence
        ):
            results = [
                self._predict_shots_on_target(x[0], x[1], max_shots)
                for x in zip(home_team, away_team)
            ]
            return results

        else:
            raise ValueError("Team data types not recognised")

    def _predict_shots_on_target(self, home_team, away_team, max_shots=15):
        """
        Predicts the probabilities of the different possible shots on target outcomes

        Parameters
        ----------
        home_team : str
            The name of the home_team, must have been in the data the model was fitted on

        away_team : str
            The name of the away_team, must have been in the data the model was fitted on

        max_shots : int
            The maximum number of shots on target to calculate the probabilities over.
            Reducing this will improve performance slightly at the expensive of accuracy

        Returns
        -------
        FootballProbabilityGrid
            A class providing access to a range of probabilities,
            such as over/unders for shots on target
        """

        # Check we have parameters for teams
        if home_team not in self.teams:
            raise ValueError(
                (
                    "No parameters for home team - "
                    "please ensure the team was included in the training data"
                )
            )

        if away_team not in self.teams:
            raise ValueError(
                (
                    "No parameters for away team - "
                    "please ensure the team was included in the training data"
                )
            )

        # Get the relevant model parameters
        home_idx = np.where(self.teams == home_team)[0][0]
        away_idx = np.where(self.teams == away_team)[0][0]

        home_attack = self._params_sot[home_idx]
        away_attack = self._params_sot[away_idx]

        home_defence = self._params_sot[home_idx + self.n_teams]
        away_defence = self._params_sot[away_idx + self.n_teams]

        home_advantage = self._params_sot[-2]
        rho = self._params_sot[-1]

        # Calculate the shots on target expectation
        home_sot = np.exp(home_advantage + home_attack + away_defence)
        away_sot = np.exp(away_attack + home_defence)
        home_sot_vector = poisson(home_sot).pmf(np.arange(0, max_shots))
        away_sot_vector = poisson(away_sot).pmf(np.arange(0, max_shots))

        # Get the probabilities for each possible shots on target score
        m = np.outer(home_sot_vector, away_sot_vector)

        # Apply Dixon and Coles adjustment
        m[0, 0] *= 1 - home_sot * away_sot * rho
        m[0, 1] *= 1 + home_sot * rho
        m[1, 0] *= 1 + away_sot * rho
        m[1, 1] *= 1 - rho

        # Return the FootballProbabilityGrid
        probability_grid = FootballProbabilityGrid(m, home_sot, away_sot)

        return probability_grid

    def get_shots_on_target_params(self):
        """
        Provides access to the model's fitted parameters for shots on target

        Returns
        -------
        dict
            A dict containing the model's parameters for shots on target
        """
        if not self.fitted_sot:
            raise ValueError(
                "Shots on target model's parameters have not been fit yet, please call the `fit_shots_on_target()` function first"
            )

        params = dict(
            zip(
                ["attack_" + team for team in self.teams]
                + ["defence_" + team for team in self.teams]
                + ["home_advantage", "rho"],
                self._params_sot,
            )
        )
        return params

# %%
def calculate_mean_rps(dc, df):
    rps_values = list()
    for idx, row in df.iterrows():
        # Get the predicted probabilities for home, draw, and away outcomes
        predictions = dc.predict(row["HomeTeam"], row["AwayTeam"]).home_draw_away

        # Append the RPS for the current prediction and outcome
        rps_values.append(calculate_rps(predictions, outcome))

    return np.mean(rps_values)

# %%
# df1 = pd.read_csv('data/prem/23-24.csv')
# df2 = pd.read_csv('data/prem/24-25.csv')

# df3 = pd.read_csv('data/france/23-24.csv')
# df4 = pd.read_csv('data/france/24-25.csv')

# df5 = pd.read_csv('data/laliga/23-24.csv')
# df6 = pd.read_csv('data/laliga/24-25.csv')

# df7 = pd.read_csv('data/portugal/23-24.csv')
# df8 = pd.read_csv('data/portugal/24-25.csv')

# df9 = pd.read_csv('data/seriea/23-24.csv')
# df10 = pd.read_csv('data/seriea/24-25.csv')

# df11 = pd.read_csv('data/bundesliga/23-24.csv')
# df12 = pd.read_csv('data/bundesliga/24-25.csv')

# df13 = pd.read_csv('data/netherlands/23-24.csv')
# df14 = pd.read_csv('data/netherlands/24-25.csv')

# df15 = pd.read_csv('data/scotland/23-24.csv')
# df16 = pd.read_csv('data/scotland/24-25.csv')

# df17 = pd.read_csv('data/belgium/23-24.csv')
# df18 = pd.read_csv('data/belgium/24-25.csv')
# df18.dropna(inplace=True)

# df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18], ignore_index=True)

df = pd.read_csv('europa_data_final.csv')

# %%
# # Sort the data by date in ascending order
# df["Date"] = pd.to_datetime(df["Date"], format='%d/%m/%Y', errors='coerce')
# df = df.sort_values(by="Date")

# rps_values = list()

# %%
from sklearn.model_selection import train_test_split
# Ensure the 'date' column is in datetime format
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d') 

train = df.copy()  # Excludes the last 466 entries
test = df.iloc[-600:].copy() 

# Calculate days since the latest date in the training set
train["days_since"] = (train["date"].max() - train["date"]).dt.days

# Check for missing teams in test compared to train
train_teams = set(train['homeTeam']).union(set(train['awayTeam']))
test_teams = set(test['homeTeam']).union(set(test['awayTeam']))
missing_teams = test_teams - train_teams

if missing_teams:
    print(f"Warning: The following teams are missing in the training data: {missing_teams}")

# Calculate weight based on dc_decay
train["weight"] = dc_decay(0.02, train["days_since"])

# Fit the model using the training data
dc = DixonColesGoalModel(
    train["homeScore"],
    train["awayScore"],
    train["homeTeam"],
    train["awayTeam"],
    train["weight"],
)
dc.fit()

# %%
# Drop rows with null values in either 'hometotalShotsOnGoal' or 'awaytotalShotsOnGoal'
df = df.dropna(subset=['hometotalShotsOnGoal', 'awaytotalShotsOnGoal'])

# %%
len(df.iloc[:-500])

# %%
train = df.iloc[:-600].copy()  # Excludes the last 466 entries
test = df.iloc[-600:].copy()   # Includes only the last 466 entries
# Calculate days since the latest date in the training set
train["days_since"] = (train["date"].max() - train["date"]).dt.days

# Check for missing teams in test compared to train
train_teams = set(train['homeTeam']).union(set(train['awayTeam']))
test_teams = set(test['homeTeam']).union(set(test['awayTeam']))
missing_teams = test_teams - train_teams

if missing_teams:
    print(f"Warning: The following teams are missing in the training data: {missing_teams}")

# Calculate weight based on dc_decay
train["weight"] = dc_decay(0.0001, train["days_since"])

# Fit the model using the training data
dc_sot = DixonColesGoalModel_sot(
    goals_home=train["homeScore"],
    goals_away=train["awayScore"],
    teams_home=train["homeTeam"],
    teams_away=train["awayTeam"],
    shots_on_target_home=train["hometotalShotsOnGoal"],
    shots_on_target_away=train["awaytotalShotsOnGoal"],
    weights=train["weight"],
)
dc_sot.fit_shots_on_target()

# %%
sot_params = dc_sot.get_shots_on_target_params()
sot_params

# %%
params = dc.get_params()
dc.get_params

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def predict_ST(params, home_team, away_team):
    """
    Predicts the number of shots for home and away teams using a Poisson model,
    calculates probabilities for over/under shot thresholds, and determines
    which team is more likely to have more shots.

    Parameters:
    - params (dict): Model parameters including attack and defence strengths,
                     home advantage, and rho for correlation.
    - home_team (str): Name of the home team.
    - away_team (str): Name of the away team.

    Returns:
    - home_shots_prob (float): Probability of home team winning in shots.
    - draw_shots_prob (float): Probability of a draw in shots.
    - away_shots_prob (float): Probability of away team winning in shots.
    - over_under_shots_team (dict): Over/Under probabilities for specified thresholds per team.
    - over_under_shots_total (dict): Over/Under probabilities for specified thresholds total shots.
    """
    # Extract parameters
    home_attack = params["attack_" + home_team]
    home_defence = params["defence_" + home_team]
    away_attack = params["attack_" + away_team]
    away_defence = params["defence_" + away_team]
    home_advantage = params["home_advantage"]
    rho = params["rho"]  # Correlation parameter for shots

    # Calculate expected shots using exponential to ensure positivity
    home_shot_expectation = np.exp(home_attack + away_defence + home_advantage)
    away_shot_expectation = np.exp(away_attack + home_defence)

    # Poisson probabilities for shots from 0 to 25 (adjust as needed)
    max_shots = 20
    home_probs = poisson.pmf(range(max_shots + 1), home_shot_expectation)
    away_probs = poisson.pmf(range(max_shots + 1), away_shot_expectation)

    # Shot probability matrix (Home Shots x Away Shots)
    m = np.outer(home_probs, away_probs)

    # Adjust for correlation (rho)
    # This simplistic adjustment modifies the (0,0), (0,1), (1,0), and (1,1) cells.
    # For a more accurate correlation adjustment, consider more sophisticated methods.
    if rho != 0:
        m[0, 0] *= 1 - home_shot_expectation * away_shot_expectation * rho
        m[0, 1] *= 1 + home_shot_expectation * rho
        m[1, 0] *= 1 + away_shot_expectation * rho
        m[1, 1] *= 1 - rho

    # Ensure all probabilities are non-negative and normalize
    m = np.maximum(m, 0)
    m /= m.sum()

    # Calculate Dominant Shot Probabilities
    home_shots_prob = np.sum(np.tril(m, -1))  # Home shots > Away shots
    draw_shots_prob = np.sum(np.diag(m))      # Home shots == Away shots
    away_shots_prob = np.sum(np.triu(m, 1))   # Away shots > Home shots

    # Print Cheat Sheet
    print(f'{home_team} VS {away_team} - Shots Prediction Cheat Sheet')
    print('============================================================')
    print(f'Probability {home_team} has more shots: {home_shots_prob:.4f}')
    print(f'Probability of a draw in shots: {draw_shots_prob:.4f}')
    print(f'Probability {away_team} has more shots: {away_shots_prob:.4f}')

    # Calculate Over/Under Shot Probabilities for Each Team
    def over_under_team_prob(probs, threshold):
        # Under probability: P(shots <= threshold)
        under_prob = np.sum(probs[:int(threshold)+1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    # Individual team shot thresholds
    team_shot_thresholds = [3, 4, 5, 7, 9]  # Adjust thresholds as needed
    over_under_shots_team = {home_team: {}, away_team: {}}

    print("\nOver/Under Shots Per Team:")
    for threshold in team_shot_thresholds:
        # Home team probabilities
        under_prob_home, over_prob_home = over_under_team_prob(home_probs, threshold)
        over_under_shots_team[home_team][threshold] = {
            'Under': under_prob_home,
            'Over': over_prob_home
        }

        # Away team probabilities
        under_prob_away, over_prob_away = over_under_team_prob(away_probs, threshold)
        over_under_shots_team[away_team][threshold] = {
            'Under': under_prob_away,
            'Over': over_prob_away
        }

        print(f"\nThreshold {threshold} Shots:")
        print(f"{home_team} - Under {threshold} shots: {under_prob_home:.4f}, Over {threshold} shots: {over_prob_home:.4f}")
        print(f"{away_team} - Under {threshold} shots: {under_prob_away:.4f}, Over {threshold} shots: {over_prob_away:.4f}")

    # Calculate Over/Under Shot Probabilities for Total Shots
    def over_under_total_prob(m, threshold):
        total_probs = np.zeros((max_shots * 2) + 1)
        for i in range(max_shots + 1):
            for j in range(max_shots + 1):
                total_probs[i + j] += m[i, j]
        # Under probability: P(total shots <= threshold)
        under_prob = np.sum(total_probs[:int(threshold)+1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    # Total shots thresholds
    total_shot_thresholds = [5, 7, 9, 11]  # Adjust thresholds as needed
    over_under_shots_total = {}
    print("\nOver/Under Total Shots:")
    for threshold in total_shot_thresholds:
        under_prob_total, over_prob_total = over_under_total_prob(m, threshold)
        over_under_shots_total[threshold] = {
            'Under': under_prob_total,
            'Over': over_prob_total
        }
        print(f"Under {threshold} total shots: {under_prob_total:.4f}, Over {threshold} total shots: {over_prob_total:.4f}")

    # Calculate Betting Odds
    def calculate_odds(prob):
        epsilon = 1e-8  # To prevent division by zero
        return 1 / (prob + epsilon)

    # Match outcome odds based on shots
    home_shots_odds = calculate_odds(home_shots_prob)
    draw_shots_odds = calculate_odds(draw_shots_prob)
    away_shots_odds = calculate_odds(away_shots_prob)

    print("\nShot Outcome Odds (Decimal):")
    print(f"{home_team} More Shots: {home_shots_odds:.2f}")
    print(f"Draw in Shots: {draw_shots_odds:.2f}")
    print(f"{away_team} More Shots: {away_shots_odds:.2f}")

    # Over/Under odds for shots per team
    print("\nOver/Under Odds Per Team:")
    for threshold in team_shot_thresholds:
        # Home team odds
        under_odds_home = calculate_odds(over_under_shots_team[home_team][threshold]['Under'])
        over_odds_home = calculate_odds(over_under_shots_team[home_team][threshold]['Over'])

        # Away team odds
        under_odds_away = calculate_odds(over_under_shots_team[away_team][threshold]['Under'])
        over_odds_away = calculate_odds(over_under_shots_team[away_team][threshold]['Over'])

        print(f"\nThreshold {threshold} Shots:")
        print(f"{home_team} - Under {threshold} shots: {under_odds_home:.2f}, Over {threshold} shots: {over_odds_home:.2f}")
        print(f"{away_team} - Under {threshold} shots: {under_odds_away:.2f}, Over {threshold} shots: {over_odds_away:.2f}")

    # Over/Under odds for total shots
    print("\nOver/Under Odds for Total Shots:")
    for threshold in total_shot_thresholds:
        under_odds_total = calculate_odds(over_under_shots_total[threshold]['Under'])
        over_odds_total = calculate_odds(over_under_shots_total[threshold]['Over'])

        print(f"Under {threshold} total shots: {under_odds_total:.2f}, Over {threshold} total shots: {over_odds_total:.2f}")

    # Optional: Plotting the Shot Probability Matrix
    # Uncomment the following lines if you wish to visualize the shot probability matrix
    plt.figure(figsize=(10, 8))
    plt.imshow(m, cmap='Greens', interpolation='nearest')
    plt.colorbar(label='Probability')
    plt.xlabel(f"{away_team} Shots")
    plt.ylabel(f"{home_team} Shots")
    plt.title(f"Shot Probability Matrix: {home_team} vs {away_team}")

    # Display the values in each cell (optional for large matrices, may clutter)
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            if m[i, j] > 0.001:  # Only display significant probabilities
                plt.text(j, i, f"{m[i, j]:.3f}", ha='center', va='center', color="black", fontsize=6)

    plt.show()


    return home_shots_prob, draw_shots_prob, away_shots_prob, over_under_shots_team, over_under_shots_total

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def predict(params, home_team, away_team):
    home_attack = params["attack_" + home_team]
    home_defence = params["defence_" + home_team]
    away_attack = params["attack_" + away_team]
    away_defence = params["defence_" + away_team]
    home_advantage = params["home_advantage"]
    rho = params["rho"]

    # Calculate expected goals using exponential to ensure positivity
    home_goal_expectation = np.exp(home_attack + away_defence + home_advantage)
    away_goal_expectation = np.exp(away_attack + home_defence)

    # Poisson probabilities for goals from 0 to 5
    max_goals = 5
    goal_range = np.arange(0, max_goals + 1)
    home_probs = poisson.pmf(goal_range, home_goal_expectation)
    away_probs = poisson.pmf(goal_range, away_goal_expectation)

    # Goal probability matrix (Home Goals x Away Goals)
    m = np.outer(home_probs, away_probs)
    
    # Adjust for correlation (if rho is used in your model)
    if rho != 0:
        m[0, 0] *= 1 - home_goal_expectation * away_goal_expectation * rho
        m[0, 1] *= 1 + home_goal_expectation * rho
        m[1, 0] *= 1 + away_goal_expectation * rho
        m[1, 1] *= 1 - rho    
    
    # Ensure the matrix sums to 1 after adjustments
    m = m / m.sum()

    # Calculate both teams to score (BTTS) probability
    p_home_zero = home_probs[0]       # P(Home = 0)
    p_away_zero = away_probs[0]       # P(Away = 0)
    p_both_score = 1 - (p_home_zero + p_away_zero - m[0, 0])

    # print(f'{home_team} VS {away_team} Cheat Sheet')
    # print('============================================================')
    # print(f'Both Teams To Score (BTTS) Probability: {p_both_score:.4f}')
    # print(f'BTTS Odds: {1/p_both_score:.4f}')

    # Calculate match outcome probabilities
    home_win_prob = np.sum(np.tril(m, -1))
    draw_prob = np.sum(np.diag(m))
    away_win_prob = np.sum(np.triu(m, 1))

    # Calculate probabilities for 'Home Win or Draw' and 'Away Win or Draw'
    home_or_draw_prob = home_win_prob + draw_prob
    away_or_draw_prob = away_win_prob + draw_prob

    # Function to calculate odds
    def calculate_odds(prob):
        epsilon = 1e-8  # To prevent division by zero
        return 1 / (prob + epsilon)

    # Calculate odds for match outcomes
    home_win_odds = calculate_odds(home_win_prob)
    draw_odds = calculate_odds(draw_prob)
    away_win_odds = calculate_odds(away_win_prob)

    # Calculate odds for 'Home Win or Draw' and 'Away Win or Draw'
    home_or_draw_odds = calculate_odds(home_or_draw_prob)
    away_or_draw_odds = calculate_odds(away_or_draw_prob)

    # Display probabilities for match outcomes
    # print("\nMatch Outcome Probabilities:")
    # print(f"Home Win Probability: {home_win_prob:.4f}")
    # print(f"Draw Probability: {draw_prob:.4f}")
    # print(f"Away Win Probability: {away_win_prob:.4f}")
    # print(f"Home Win or Draw Probability: {home_or_draw_prob:.4f}")
    # print(f"Away Win or Draw Probability: {away_or_draw_prob:.4f}")

    # # Display odds for match outcomes
    # print("\nMatch Outcome Odds (Decimal):")
    # print(f"Home Win Odds: {home_win_odds:.2f}")
    # print(f"Draw Odds: {draw_odds:.2f}")
    # print(f"Away Win Odds: {away_win_odds:.2f}")
    # print(f"Home Win or Draw Odds: {home_or_draw_odds:.2f}")
    # print(f"Away Win or Draw Odds: {away_or_draw_odds:.2f}")

    # Calculate total goals probabilities
    max_total_goals = 2 * max_goals  # Maximum possible total goals
    total_goals_probs = np.zeros(max_total_goals + 1)
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            total_goals = i + j
            total_goals_probs[total_goals] += m[i, j]

    # Calculate over/under probabilities for total goals
    def over_under_total_prob(threshold):
        under_prob = np.sum(total_goals_probs[:int(np.floor(threshold)) + 1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    total_thresholds = [1.5, 2.5, 3.5]
    over_under_total_results = {}
    for threshold in total_thresholds:
        under_prob, over_prob = over_under_total_prob(threshold)
        over_under_total_results[threshold] = {
            'Under': under_prob,
            'Over': over_prob
        }
        #print(f"Under {threshold} total goals: {under_prob:.4f}, Over {threshold} total goals: {over_prob:.4f}")

    # Over/Under odds for total goals
    #print("\nOver/Under Total Goals Odds (Decimal):")
    for threshold in total_thresholds:
        under_odds = calculate_odds(over_under_total_results[threshold]['Under'])
        over_odds = calculate_odds(over_under_total_results[threshold]['Over'])
        #print(f"Under {threshold} total goals: {under_odds:.2f}, Over {threshold} total goals: {over_odds:.2f}")

    # Calculate over/under probabilities for individual team goals
    def over_under_team_prob(probs, threshold):
        # Under probability: P(goals <= floor(threshold))
        under_prob = np.sum(probs[:int(np.floor(threshold)) + 1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    team_thresholds = [0.5, 1.5, 2.5, 3.5]
    over_under_team_results = {home_team: {}, away_team: {}}

    for threshold in team_thresholds:
        # Home team over/under
        under_prob_home, over_prob_home = over_under_team_prob(home_probs, threshold)
        over_under_team_results[home_team][threshold] = {
            'Under': under_prob_home,
            'Over': over_prob_home
        }

        # Away team over/under
        under_prob_away, over_prob_away = over_under_team_prob(away_probs, threshold)
        over_under_team_results[away_team][threshold] = {
            'Under': under_prob_away,
            'Over': over_prob_away
        }

    # Over/Under odds for individual team goals
    #print("\nOver/Under Goals Odds per Team (Decimal):")
    for team in [home_team, away_team]:
        #print(f"\n{team}:")
        for threshold in team_thresholds:
            under_prob = over_under_team_results[team][threshold]['Under']
            over_prob = over_under_team_results[team][threshold]['Over']
            under_odds = calculate_odds(under_prob)
            over_odds = calculate_odds(over_prob)
            #print(f"  Under {threshold} goals: {under_odds:.2f}, Over {threshold} goals: {over_odds:.2f}")

    # Calculate probabilities for goal ranges
    goal_ranges = {
        '0-2 Goals': (0, 2),
        '1-3 Goals': (1, 3),
        '1-4 Goals': (1, 4),
        '2-3 Goals': (2, 3),
        '2-4 Goals': (2, 4),
        '4+ Goals': (4, max_total_goals)
    }

    goal_range_probs = {}
    for range_name, (start, end) in goal_ranges.items():
        # For '4+ Goals', include all goals from 4 to max_total_goals
        if end == max_total_goals:
            prob = np.sum(total_goals_probs[start:])
        else:
            prob = np.sum(total_goals_probs[start:end + 1])
        goal_range_probs[range_name] = prob

    # Display goal range probabilities and odds
    #print("\nGoal Range Probabilities and Odds:")
    for range_name, prob in goal_range_probs.items():
        odds = calculate_odds(prob)
        #print(f"{range_name}: Probability = {prob:.4f}, Odds = {odds:.2f}")

    # Return the calculated probabilities and odds as needed
    return {
        'home_win_prob': home_win_prob,
        'draw_prob': draw_prob,
        'away_win_prob': away_win_prob,
        'home_or_draw_prob': home_or_draw_prob,
        'away_or_draw_prob': away_or_draw_prob,
        'home_win_odds': home_win_odds,
        'draw_odds': draw_odds,
        'away_win_odds': away_win_odds,
        'home_or_draw_odds': home_or_draw_odds,
        'away_or_draw_odds': away_or_draw_odds,
        'over_under_total_results': over_under_total_results,
        'over_under_team_results': over_under_team_results,
        'goal_range_probs': goal_range_probs,
        'matrix':m,
    }

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
from collections import defaultdict

# Assume DixonColesGoalModel and predict function are already defined and accept weights

def dc_decay(x, t):
    return np.exp(-x * t)

# Read your dataframe
df = pd.read_csv('europa_data_final.csv')  # Replace with your actual data source

# Convert 'date' column to datetime using the correct format
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# Sort the dataframe by date
df = df.sort_values('date')

# Group the dataframe by week and year
df['year_week'] = df['date'].dt.isocalendar().year.astype(str) + '-' + df['date'].dt.isocalendar().week.astype(str).str.zfill(2)

# Create directories to store matrices and next_week_games if they don't exist
os.makedirs('matrices', exist_ok=True)
os.makedirs('next_week_games', exist_ok=True)  # New directory for next_week_games CSV files

# Get the list of year_week periods
weeks = sorted(df['year_week'].unique())

# Iterate over the weeks
for i in range(len(weeks) - 1):
    current_week = weeks[i]
    next_week = weeks[i + 1]
    
    print(f"\nProcessing Week: {current_week}")
    
    # Get data up to the current week (inclusive)
    cumulative_data = df[df['year_week'] <= current_week].copy()
    
    # Calculate 'days_since' and 'weight'
    max_date = cumulative_data['date'].max()
    cumulative_data['days_since'] = (max_date - cumulative_data['date']).dt.days
    cumulative_data['weight'] = dc_decay(0.02, cumulative_data['days_since'])
    
    # Prepare data for the model
    goals_home = cumulative_data['homeScore']
    goals_away = cumulative_data['awayScore']
    teams_home = cumulative_data['homeTeam']
    teams_away = cumulative_data['awayTeam']
    weights = cumulative_data['weight']
    
    # Initialize and fit the model with weights
    model = DixonColesGoalModel(goals_home, goals_away, teams_home, teams_away, weights=weights)
    model.fit()
    
    # Get the parameters
    params = model.get_params()
    
    # Get games for the next week
    next_week_games = df[df['year_week'] == next_week].copy()
    
    # Check if there are games in the next week
    if next_week_games.empty:
        print(f"No games found for week: {next_week}")
        continue
    
    # Add attack and defense parameters to the teams in the next week's games
    def get_attack_param(team):
        return params.get(f"attack_{team}", np.nan)
    
    def get_defense_param(team):
        return params.get(f"defence_{team}", np.nan)
    
    next_week_games['home_attack_param'] = next_week_games['homeTeam'].apply(get_attack_param)
    next_week_games['home_defense_param'] = next_week_games['homeTeam'].apply(get_defense_param)
    next_week_games['away_attack_param'] = next_week_games['awayTeam'].apply(get_attack_param)
    next_week_games['away_defense_param'] = next_week_games['awayTeam'].apply(get_defense_param)
    
    # Identify games with uninitialized teams
    skipped_games = next_week_games[next_week_games.isna().any(axis=1)]
    for idx, game in skipped_games.iterrows():
        print(f"Skipping Event ID {game['eventId']} due to uninitialized team(s)")
    
    # Drop games where any attack or defense parameter is NaN
    valid_games = next_week_games.dropna(subset=[
        'home_attack_param', 'home_defense_param',
        'away_attack_param', 'away_defense_param'
    ])
    
    # Iterate over the valid games
    for idx, game in valid_games.iterrows():
        home_team = game['homeTeam']
        away_team = game['awayTeam']
        event_id = game['eventId']
        
        # Use the predict function
        prediction = predict(params, home_team, away_team)
        
        # Store the matrix in a file named after the eventId
        matrix = prediction['matrix']
        matrix_file = f"matrices/{event_id}.csv"
        np.savetxt(matrix_file, matrix, delimiter=',')
        
        print(f"Stored prediction matrix for Event ID {event_id}")
    
    # Save the updated next_week_games with parameters in the 'next_week_games' directory
    next_week_games_file = f"next_week_games/next_week_games_{next_week}.csv"
    next_week_games.to_csv(next_week_games_file, index=False)
# Out:
# Processing Week: 2023-08
# Skipping Event ID 10952495 due to uninitialized team(s)
# Skipping Event ID 10952498 due to uninitialized team(s)
# Skipping Event ID 10952494 due to uninitialized team(s)
# Skipping Event ID 10952486 due to uninitialized team(s)
# Skipping Event ID 10952481 due to uninitialized team(s)
# Skipping Event ID 10952480 due to uninitialized team(s)
# Skipping Event ID 10952483 due to uninitialized team(s)
# Skipping Event ID 10952485 due to uninitialized team(s)
# Skipping Event ID 10952488 due to uninitialized team(s)
# Skipping Event ID 10952484 due to uninitialized team(s)
# Skipping Event ID 10952492 due to uninitialized team(s)
# Skipping Event ID 10952489 due to uninitialized team(s)
# Skipping Event ID 10952490 due to uninitialized team(s)
# Skipping Event ID 10952493 due to uninitialized team(s)
# Skipping Event ID 10952491 due to uninitialized team(s)
# Skipping Event ID 10952487 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952481
# Stored prediction matrix for Event ID 10952488
# Stored prediction matrix for Event ID 10952484
# Stored prediction matrix for Event ID 10952492
# Stored prediction matrix for Event ID 10952489
# Stored prediction matrix for Event ID 10952490
# Stored prediction matrix for Event ID 10952493
# Stored prediction matrix for Event ID 10952491
# Stored prediction matrix for Event ID 10952487
#
# Processing Week: 2023-09
# Skipping Event ID 10952478 due to uninitialized team(s)
# Skipping Event ID 10952479 due to uninitialized team(s)
# Skipping Event ID 10952469 due to uninitialized team(s)
# Skipping Event ID 10952468 due to uninitialized team(s)
# Skipping Event ID 10952471 due to uninitialized team(s)
# Skipping Event ID 10952470 due to uninitialized team(s)
# Skipping Event ID 10952472 due to uninitialized team(s)
# Skipping Event ID 10952474 due to uninitialized team(s)
# Skipping Event ID 10952482 due to uninitialized team(s)
# Skipping Event ID 10952477 due to uninitialized team(s)
# Skipping Event ID 10952475 due to uninitialized team(s)
# Skipping Event ID 10952476 due to uninitialized team(s)
# Skipping Event ID 10952473 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952478
# Stored prediction matrix for Event ID 10952479
# Stored prediction matrix for Event ID 10952469
# Stored prediction matrix for Event ID 10952468
# Stored prediction matrix for Event ID 10952471
# Stored prediction matrix for Event ID 10952470
# Stored prediction matrix for Event ID 10952472
# Stored prediction matrix for Event ID 10952474
# Stored prediction matrix for Event ID 10952482
# Stored prediction matrix for Event ID 10952477
# Stored prediction matrix for Event ID 10952475
# Stored prediction matrix for Event ID 10952476
# Stored prediction matrix for Event ID 10952473
#
# Processing Week: 2023-10
# Skipping Event ID 10952467 due to uninitialized team(s)
# Skipping Event ID 10952463 due to uninitialized team(s)
# Skipping Event ID 10952459 due to uninitialized team(s)
# Skipping Event ID 10952464 due to uninitialized team(s)
# Skipping Event ID 10952461 due to uninitialized team(s)
# Skipping Event ID 10952465 due to uninitialized team(s)
# Skipping Event ID 10952460 due to uninitialized team(s)
# Skipping Event ID 10952462 due to uninitialized team(s)
# Skipping Event ID 10952466 due to uninitialized team(s)
# Skipping Event ID 10952454 due to uninitialized team(s)
# Skipping Event ID 10952456 due to uninitialized team(s)
# Skipping Event ID 10952453 due to uninitialized team(s)
# Skipping Event ID 10952458 due to uninitialized team(s)
# Skipping Event ID 10952455 due to uninitialized team(s)
# Skipping Event ID 10952457 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952467
# Stored prediction matrix for Event ID 10952463
# Stored prediction matrix for Event ID 10952459
# Stored prediction matrix for Event ID 10952464
# Stored prediction matrix for Event ID 10952461
# Stored prediction matrix for Event ID 10952465
# Stored prediction matrix for Event ID 10952460
# Stored prediction matrix for Event ID 10952462
# Stored prediction matrix for Event ID 10952466
# Stored prediction matrix for Event ID 10952454
# Stored prediction matrix for Event ID 10952456
# Stored prediction matrix for Event ID 10952453
# Stored prediction matrix for Event ID 10952458
# Stored prediction matrix for Event ID 10952455
# Stored prediction matrix for Event ID 10952457
#
# Processing Week: 2023-11
# Skipping Event ID 10952452 due to uninitialized team(s)
# Skipping Event ID 10952449 due to uninitialized team(s)
# Skipping Event ID 10952451 due to uninitialized team(s)
# Skipping Event ID 10952448 due to uninitialized team(s)
# Skipping Event ID 10952446 due to uninitialized team(s)
# Skipping Event ID 10952450 due to uninitialized team(s)
# Skipping Event ID 10952441 due to uninitialized team(s)
# Skipping Event ID 10952439 due to uninitialized team(s)
# Skipping Event ID 10952445 due to uninitialized team(s)
# Skipping Event ID 10952437 due to uninitialized team(s)
# Skipping Event ID 10952444 due to uninitialized team(s)
# Skipping Event ID 10952442 due to uninitialized team(s)
# Skipping Event ID 10952443 due to uninitialized team(s)
# Skipping Event ID 10952447 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952452
# Stored prediction matrix for Event ID 10952449
# Stored prediction matrix for Event ID 10952451
# Stored prediction matrix for Event ID 10952448
# Stored prediction matrix for Event ID 10952446
# Stored prediction matrix for Event ID 10952450
# Stored prediction matrix for Event ID 10952441
# Stored prediction matrix for Event ID 10952439
# Stored prediction matrix for Event ID 10952445
# Stored prediction matrix for Event ID 10952437
# Stored prediction matrix for Event ID 10952444
# Stored prediction matrix for Event ID 10952442
# Stored prediction matrix for Event ID 10952443
# Stored prediction matrix for Event ID 10952447
#
# Processing Week: 2023-12
# Skipping Event ID 10952425 due to uninitialized team(s)
# Skipping Event ID 10952427 due to uninitialized team(s)
# Skipping Event ID 10952426 due to uninitialized team(s)
# Skipping Event ID 10952428 due to uninitialized team(s)
# Skipping Event ID 10952429 due to uninitialized team(s)
# Skipping Event ID 10952434 due to uninitialized team(s)
# Skipping Event ID 10952431 due to uninitialized team(s)
# Skipping Event ID 10952432 due to uninitialized team(s)
# Skipping Event ID 10952438 due to uninitialized team(s)
# Skipping Event ID 10952440 due to uninitialized team(s)
# Skipping Event ID 10952430 due to uninitialized team(s)
# Skipping Event ID 10952433 due to uninitialized team(s)
# Skipping Event ID 10952436 due to uninitialized team(s)
# Skipping Event ID 10952435 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952425
# Stored prediction matrix for Event ID 10952427
# Stored prediction matrix for Event ID 10952426
# Stored prediction matrix for Event ID 10952428
# Stored prediction matrix for Event ID 10952429
# Stored prediction matrix for Event ID 10952434
# Stored prediction matrix for Event ID 10952431
# Stored prediction matrix for Event ID 10952432
# Stored prediction matrix for Event ID 10952438
# Stored prediction matrix for Event ID 10952440
# Stored prediction matrix for Event ID 10952430
# Stored prediction matrix for Event ID 10952433
# Stored prediction matrix for Event ID 10952436
# Stored prediction matrix for Event ID 10952435
#
# Processing Week: 2023-13
# Skipping Event ID 10952416 due to uninitialized team(s)
# Skipping Event ID 10952413 due to uninitialized team(s)
# Skipping Event ID 10952411 due to uninitialized team(s)
# Skipping Event ID 10952412 due to uninitialized team(s)
# Skipping Event ID 10952419 due to uninitialized team(s)
# Skipping Event ID 10952418 due to uninitialized team(s)
# Skipping Event ID 10952414 due to uninitialized team(s)
# Skipping Event ID 10952422 due to uninitialized team(s)
# Skipping Event ID 10952415 due to uninitialized team(s)
# Skipping Event ID 10952424 due to uninitialized team(s)
# Skipping Event ID 10952421 due to uninitialized team(s)
# Skipping Event ID 10952420 due to uninitialized team(s)
# Skipping Event ID 10952417 due to uninitialized team(s)
# Skipping Event ID 10952423 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952416
# Stored prediction matrix for Event ID 10952413
# Stored prediction matrix for Event ID 10952411
# Stored prediction matrix for Event ID 10952412
# Stored prediction matrix for Event ID 10952419
# Stored prediction matrix for Event ID 10952418
# Stored prediction matrix for Event ID 10952414
# Stored prediction matrix for Event ID 10952422
# Stored prediction matrix for Event ID 10952415
# Stored prediction matrix for Event ID 10952424
# Stored prediction matrix for Event ID 10952421
# Stored prediction matrix for Event ID 10952420
# Stored prediction matrix for Event ID 10952417
# Stored prediction matrix for Event ID 10952423
#
# Processing Week: 2023-14
# Skipping Event ID 11067265 due to uninitialized team(s)
# Skipping Event ID 11067275 due to uninitialized team(s)
# Skipping Event ID 11067269 due to uninitialized team(s)
# Skipping Event ID 11067277 due to uninitialized team(s)
# Skipping Event ID 11067266 due to uninitialized team(s)
# Skipping Event ID 11067273 due to uninitialized team(s)
# Skipping Event ID 10952403 due to uninitialized team(s)
# Skipping Event ID 11067271 due to uninitialized team(s)
# Skipping Event ID 10952397 due to uninitialized team(s)
# Skipping Event ID 11067264 due to uninitialized team(s)
# Skipping Event ID 11067267 due to uninitialized team(s)
# Skipping Event ID 10952400 due to uninitialized team(s)
# Skipping Event ID 10952398 due to uninitialized team(s)
# Skipping Event ID 10952399 due to uninitialized team(s)
# Skipping Event ID 10952402 due to uninitialized team(s)
# Skipping Event ID 10952401 due to uninitialized team(s)
# Skipping Event ID 10952404 due to uninitialized team(s)
# Skipping Event ID 11067270 due to uninitialized team(s)
# Skipping Event ID 10952405 due to uninitialized team(s)
# Skipping Event ID 10952407 due to uninitialized team(s)
# Skipping Event ID 10952410 due to uninitialized team(s)
# Skipping Event ID 10952408 due to uninitialized team(s)
# Skipping Event ID 10952406 due to uninitialized team(s)
# Skipping Event ID 10952409 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952403
# Stored prediction matrix for Event ID 10952397
# Stored prediction matrix for Event ID 10952400
# Stored prediction matrix for Event ID 10952398
# Stored prediction matrix for Event ID 10952399
# Stored prediction matrix for Event ID 10952402
# Stored prediction matrix for Event ID 10952401
# Stored prediction matrix for Event ID 10952404
# Stored prediction matrix for Event ID 10952405
# Stored prediction matrix for Event ID 10952407
# Stored prediction matrix for Event ID 10952410
# Stored prediction matrix for Event ID 10952408
# Stored prediction matrix for Event ID 10952406
# Stored prediction matrix for Event ID 10952409
#
# Processing Week: 2023-15
# Skipping Event ID 11067286 due to uninitialized team(s)
# Skipping Event ID 11067311 due to uninitialized team(s)
# Skipping Event ID 11067282 due to uninitialized team(s)
# Skipping Event ID 11067294 due to uninitialized team(s)
# Skipping Event ID 11067306 due to uninitialized team(s)
# Skipping Event ID 10952382 due to uninitialized team(s)
# Skipping Event ID 11067291 due to uninitialized team(s)
# Skipping Event ID 11067284 due to uninitialized team(s)
# Skipping Event ID 11067302 due to uninitialized team(s)
# Skipping Event ID 10952384 due to uninitialized team(s)
# Skipping Event ID 10952385 due to uninitialized team(s)
# Skipping Event ID 10952386 due to uninitialized team(s)
# Skipping Event ID 10952387 due to uninitialized team(s)
# Skipping Event ID 10952395 due to uninitialized team(s)
# Skipping Event ID 10952388 due to uninitialized team(s)
# Skipping Event ID 11067298 due to uninitialized team(s)
# Skipping Event ID 10952389 due to uninitialized team(s)
# Skipping Event ID 10952393 due to uninitialized team(s)
# Skipping Event ID 10952394 due to uninitialized team(s)
# Skipping Event ID 10952392 due to uninitialized team(s)
# Skipping Event ID 10952391 due to uninitialized team(s)
# Skipping Event ID 10952396 due to uninitialized team(s)
# Skipping Event ID 10952390 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067286
# Stored prediction matrix for Event ID 11067311
# Stored prediction matrix for Event ID 11067282
# Stored prediction matrix for Event ID 11067294
# Stored prediction matrix for Event ID 11067306
# Stored prediction matrix for Event ID 10952382
# Stored prediction matrix for Event ID 11067291
# Stored prediction matrix for Event ID 11067284
# Stored prediction matrix for Event ID 11067302
# Stored prediction matrix for Event ID 10952384
# Stored prediction matrix for Event ID 10952385
# Stored prediction matrix for Event ID 10952386
# Stored prediction matrix for Event ID 10952387
# Stored prediction matrix for Event ID 10952395
# Stored prediction matrix for Event ID 10952388
# Stored prediction matrix for Event ID 11067298
# Stored prediction matrix for Event ID 10952389
# Stored prediction matrix for Event ID 10952393
# Stored prediction matrix for Event ID 10952394
# Stored prediction matrix for Event ID 10952392
# Stored prediction matrix for Event ID 10952391
# Stored prediction matrix for Event ID 10952396
# Stored prediction matrix for Event ID 10952390
#
# Processing Week: 2023-16
# Skipping Event ID 11067308 due to uninitialized team(s)
# Skipping Event ID 11067321 due to uninitialized team(s)
# Skipping Event ID 11067326 due to uninitialized team(s)
# Skipping Event ID 11067324 due to uninitialized team(s)
# Skipping Event ID 11067335 due to uninitialized team(s)
# Skipping Event ID 10952381 due to uninitialized team(s)
# Skipping Event ID 11067339 due to uninitialized team(s)
# Skipping Event ID 10952371 due to uninitialized team(s)
# Skipping Event ID 10952370 due to uninitialized team(s)
# Skipping Event ID 11067330 due to uninitialized team(s)
# Skipping Event ID 11067333 due to uninitialized team(s)
# Skipping Event ID 11067341 due to uninitialized team(s)
# Skipping Event ID 10952373 due to uninitialized team(s)
# Skipping Event ID 11067315 due to uninitialized team(s)
# Skipping Event ID 10952375 due to uninitialized team(s)
# Skipping Event ID 10952383 due to uninitialized team(s)
# Skipping Event ID 10952376 due to uninitialized team(s)
# Skipping Event ID 10952378 due to uninitialized team(s)
# Skipping Event ID 10952377 due to uninitialized team(s)
# Skipping Event ID 10952379 due to uninitialized team(s)
# Skipping Event ID 10952380 due to uninitialized team(s)
# Skipping Event ID 10952374 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067308
# Stored prediction matrix for Event ID 11067321
# Stored prediction matrix for Event ID 11067326
# Stored prediction matrix for Event ID 11067324
# Stored prediction matrix for Event ID 11067335
# Stored prediction matrix for Event ID 10952381
# Stored prediction matrix for Event ID 11067339
# Stored prediction matrix for Event ID 10952371
# Stored prediction matrix for Event ID 10952370
# Stored prediction matrix for Event ID 11067330
# Stored prediction matrix for Event ID 11067333
# Stored prediction matrix for Event ID 11067341
# Stored prediction matrix for Event ID 10952373
# Stored prediction matrix for Event ID 11067315
# Stored prediction matrix for Event ID 10952375
# Stored prediction matrix for Event ID 10952383
# Stored prediction matrix for Event ID 10952376
# Stored prediction matrix for Event ID 10952378
# Stored prediction matrix for Event ID 10952377
# Stored prediction matrix for Event ID 10952379
# Stored prediction matrix for Event ID 10952380
# Stored prediction matrix for Event ID 10952374
#
# Processing Week: 2023-17
# Skipping Event ID 10952368 due to uninitialized team(s)
# Skipping Event ID 11067317 due to uninitialized team(s)
# Skipping Event ID 11067359 due to uninitialized team(s)
# Skipping Event ID 11067369 due to uninitialized team(s)
# Skipping Event ID 11067372 due to uninitialized team(s)
# Skipping Event ID 11067366 due to uninitialized team(s)
# Skipping Event ID 11067350 due to uninitialized team(s)
# Skipping Event ID 10952357 due to uninitialized team(s)
# Skipping Event ID 11067357 due to uninitialized team(s)
# Skipping Event ID 11067348 due to uninitialized team(s)
# Skipping Event ID 11067363 due to uninitialized team(s)
# Skipping Event ID 10952355 due to uninitialized team(s)
# Skipping Event ID 10952356 due to uninitialized team(s)
# Skipping Event ID 10952367 due to uninitialized team(s)
# Skipping Event ID 10952359 due to uninitialized team(s)
# Skipping Event ID 10952361 due to uninitialized team(s)
# Skipping Event ID 10952364 due to uninitialized team(s)
# Skipping Event ID 10952363 due to uninitialized team(s)
# Skipping Event ID 10952369 due to uninitialized team(s)
# Skipping Event ID 10952365 due to uninitialized team(s)
# Skipping Event ID 10952358 due to uninitialized team(s)
# Skipping Event ID 11067344 due to uninitialized team(s)
# Skipping Event ID 10952362 due to uninitialized team(s)
# Skipping Event ID 10952366 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952368
# Stored prediction matrix for Event ID 11067317
# Stored prediction matrix for Event ID 11067359
# Stored prediction matrix for Event ID 11067369
# Stored prediction matrix for Event ID 11067372
# Stored prediction matrix for Event ID 11067366
# Stored prediction matrix for Event ID 11067350
# Stored prediction matrix for Event ID 10952357
# Stored prediction matrix for Event ID 11067357
# Stored prediction matrix for Event ID 11067348
# Stored prediction matrix for Event ID 11067363
# Stored prediction matrix for Event ID 10952355
# Stored prediction matrix for Event ID 10952356
# Stored prediction matrix for Event ID 10952367
# Stored prediction matrix for Event ID 10952359
# Stored prediction matrix for Event ID 10952361
# Stored prediction matrix for Event ID 10952364
# Stored prediction matrix for Event ID 10952363
# Stored prediction matrix for Event ID 10952369
# Stored prediction matrix for Event ID 10952365
# Stored prediction matrix for Event ID 10952358
# Stored prediction matrix for Event ID 11067344
# Stored prediction matrix for Event ID 10952362
# Stored prediction matrix for Event ID 10952366
#
# Processing Week: 2023-18
# Skipping Event ID 11067354 due to uninitialized team(s)
# Skipping Event ID 11067383 due to uninitialized team(s)
# Skipping Event ID 11067395 due to uninitialized team(s)
# Skipping Event ID 11067386 due to uninitialized team(s)
# Skipping Event ID 11067397 due to uninitialized team(s)
# Skipping Event ID 11067377 due to uninitialized team(s)
# Skipping Event ID 11067380 due to uninitialized team(s)
# Skipping Event ID 11067389 due to uninitialized team(s)
# Skipping Event ID 11067374 due to uninitialized team(s)
# Skipping Event ID 11067404 due to uninitialized team(s)
# Skipping Event ID 11067400 due to uninitialized team(s)
# Skipping Event ID 10952354 due to uninitialized team(s)
# Skipping Event ID 11067435 due to uninitialized team(s)
# Skipping Event ID 11067415 due to uninitialized team(s)
# Skipping Event ID 11067406 due to uninitialized team(s)
# Skipping Event ID 11067433 due to uninitialized team(s)
# Skipping Event ID 11067438 due to uninitialized team(s)
# Skipping Event ID 11067429 due to uninitialized team(s)
# Skipping Event ID 11067411 due to uninitialized team(s)
# Skipping Event ID 11067419 due to uninitialized team(s)
# Skipping Event ID 10952342 due to uninitialized team(s)
# Skipping Event ID 10952343 due to uninitialized team(s)
# Skipping Event ID 10952344 due to uninitialized team(s)
# Skipping Event ID 10952346 due to uninitialized team(s)
# Skipping Event ID 11067423 due to uninitialized team(s)
# Skipping Event ID 10952347 due to uninitialized team(s)
# Skipping Event ID 11067426 due to uninitialized team(s)
# Skipping Event ID 10952351 due to uninitialized team(s)
# Skipping Event ID 10952349 due to uninitialized team(s)
# Skipping Event ID 10952353 due to uninitialized team(s)
# Skipping Event ID 10952350 due to uninitialized team(s)
# Skipping Event ID 10952345 due to uninitialized team(s)
# Skipping Event ID 10952352 due to uninitialized team(s)
# Skipping Event ID 10952348 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067354
# Stored prediction matrix for Event ID 11067383
# Stored prediction matrix for Event ID 11067395
# Stored prediction matrix for Event ID 11067386
# Stored prediction matrix for Event ID 11067397
# Stored prediction matrix for Event ID 11067377
# Stored prediction matrix for Event ID 11067380
# Stored prediction matrix for Event ID 11067389
# Stored prediction matrix for Event ID 11067374
# Stored prediction matrix for Event ID 11067404
# Stored prediction matrix for Event ID 11067400
# Stored prediction matrix for Event ID 10952354
# Stored prediction matrix for Event ID 11067435
# Stored prediction matrix for Event ID 11067415
# Stored prediction matrix for Event ID 11067406
# Stored prediction matrix for Event ID 11067433
# Stored prediction matrix for Event ID 11067438
# Stored prediction matrix for Event ID 11067429
# Stored prediction matrix for Event ID 11067411
# Stored prediction matrix for Event ID 11067419
# Stored prediction matrix for Event ID 10952342
# Stored prediction matrix for Event ID 10952343
# Stored prediction matrix for Event ID 10952344
# Stored prediction matrix for Event ID 10952346
# Stored prediction matrix for Event ID 11067423
# Stored prediction matrix for Event ID 10952347
# Stored prediction matrix for Event ID 11067426
# Stored prediction matrix for Event ID 10952351
# Stored prediction matrix for Event ID 10952349
# Stored prediction matrix for Event ID 10952353
# Stored prediction matrix for Event ID 10952350
# Stored prediction matrix for Event ID 10952345
# Stored prediction matrix for Event ID 10952352
# Stored prediction matrix for Event ID 10952348
#
# Processing Week: 2023-19
# Skipping Event ID 10952340 due to uninitialized team(s)
# Skipping Event ID 10952329 due to uninitialized team(s)
# Skipping Event ID 10952327 due to uninitialized team(s)
# Skipping Event ID 10952332 due to uninitialized team(s)
# Skipping Event ID 10952331 due to uninitialized team(s)
# Skipping Event ID 10952333 due to uninitialized team(s)
# Skipping Event ID 10952330 due to uninitialized team(s)
# Skipping Event ID 10952341 due to uninitialized team(s)
# Skipping Event ID 10952335 due to uninitialized team(s)
# Skipping Event ID 10952337 due to uninitialized team(s)
# Skipping Event ID 10952334 due to uninitialized team(s)
# Skipping Event ID 10952338 due to uninitialized team(s)
# Skipping Event ID 10952339 due to uninitialized team(s)
# Skipping Event ID 10952336 due to uninitialized team(s)
# Skipping Event ID 11067444 due to uninitialized team(s)
# Skipping Event ID 11067447 due to uninitialized team(s)
# Skipping Event ID 11067465 due to uninitialized team(s)
# Skipping Event ID 11067468 due to uninitialized team(s)
# Skipping Event ID 11067471 due to uninitialized team(s)
# Skipping Event ID 11067453 due to uninitialized team(s)
# Skipping Event ID 11067460 due to uninitialized team(s)
# Skipping Event ID 11067441 due to uninitialized team(s)
# Skipping Event ID 10952316 due to uninitialized team(s)
# Skipping Event ID 10952314 due to uninitialized team(s)
# Skipping Event ID 10952315 due to uninitialized team(s)
# Skipping Event ID 10952317 due to uninitialized team(s)
# Skipping Event ID 10952318 due to uninitialized team(s)
# Skipping Event ID 10952321 due to uninitialized team(s)
# Skipping Event ID 10952320 due to uninitialized team(s)
# Skipping Event ID 11067450 due to uninitialized team(s)
# Skipping Event ID 10952326 due to uninitialized team(s)
# Skipping Event ID 10952325 due to uninitialized team(s)
# Skipping Event ID 10952322 due to uninitialized team(s)
# Skipping Event ID 10952323 due to uninitialized team(s)
# Skipping Event ID 10952324 due to uninitialized team(s)
# Skipping Event ID 10952328 due to uninitialized team(s)
# Skipping Event ID 10952319 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952340
# Stored prediction matrix for Event ID 10952329
# Stored prediction matrix for Event ID 10952327
# Stored prediction matrix for Event ID 10952332
# Stored prediction matrix for Event ID 10952331
# Stored prediction matrix for Event ID 10952333
# Stored prediction matrix for Event ID 10952330
# Stored prediction matrix for Event ID 10952341
# Stored prediction matrix for Event ID 10952335
# Stored prediction matrix for Event ID 10952337
# Stored prediction matrix for Event ID 10952334
# Stored prediction matrix for Event ID 10952338
# Stored prediction matrix for Event ID 10952339
# Stored prediction matrix for Event ID 10952336
# Stored prediction matrix for Event ID 11067444
# Stored prediction matrix for Event ID 11067447
# Stored prediction matrix for Event ID 11067465
# Stored prediction matrix for Event ID 11067468
# Stored prediction matrix for Event ID 11067471
# Stored prediction matrix for Event ID 11067453
# Stored prediction matrix for Event ID 11067460
# Stored prediction matrix for Event ID 11067441
# Stored prediction matrix for Event ID 10952316
# Stored prediction matrix for Event ID 10952314
# Stored prediction matrix for Event ID 10952315
# Stored prediction matrix for Event ID 10952317
# Stored prediction matrix for Event ID 10952318
# Stored prediction matrix for Event ID 10952321
# Stored prediction matrix for Event ID 10952320
# Stored prediction matrix for Event ID 11067450
# Stored prediction matrix for Event ID 10952326
# Stored prediction matrix for Event ID 10952325
# Stored prediction matrix for Event ID 10952322
# Stored prediction matrix for Event ID 10952323
# Stored prediction matrix for Event ID 10952324
# Stored prediction matrix for Event ID 10952328
# Stored prediction matrix for Event ID 10952319
#
# Processing Week: 2023-20
# Skipping Event ID 11067457 due to uninitialized team(s)
# Skipping Event ID 11067474 due to uninitialized team(s)
# Skipping Event ID 11067508 due to uninitialized team(s)
# Skipping Event ID 11067504 due to uninitialized team(s)
# Skipping Event ID 11067500 due to uninitialized team(s)
# Skipping Event ID 11067478 due to uninitialized team(s)
# Skipping Event ID 11067492 due to uninitialized team(s)
# Skipping Event ID 11067490 due to uninitialized team(s)
# Skipping Event ID 11067498 due to uninitialized team(s)
# Skipping Event ID 11067485 due to uninitialized team(s)
# Skipping Event ID 10952302 due to uninitialized team(s)
# Skipping Event ID 10952303 due to uninitialized team(s)
# Skipping Event ID 10952301 due to uninitialized team(s)
# Skipping Event ID 10952307 due to uninitialized team(s)
# Skipping Event ID 10952304 due to uninitialized team(s)
# Skipping Event ID 10952305 due to uninitialized team(s)
# Skipping Event ID 10952308 due to uninitialized team(s)
# Skipping Event ID 11067482 due to uninitialized team(s)
# Skipping Event ID 10952310 due to uninitialized team(s)
# Skipping Event ID 10952311 due to uninitialized team(s)
# Skipping Event ID 10952313 due to uninitialized team(s)
# Skipping Event ID 10952312 due to uninitialized team(s)
# Skipping Event ID 10952309 due to uninitialized team(s)
# Skipping Event ID 10952306 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067457
# Stored prediction matrix for Event ID 11067474
# Stored prediction matrix for Event ID 11067508
# Stored prediction matrix for Event ID 11067504
# Stored prediction matrix for Event ID 11067500
# Stored prediction matrix for Event ID 11067478
# Stored prediction matrix for Event ID 11067492
# Stored prediction matrix for Event ID 11067490
# Stored prediction matrix for Event ID 11067498
# Stored prediction matrix for Event ID 11067485
# Stored prediction matrix for Event ID 10952302
# Stored prediction matrix for Event ID 10952303
# Stored prediction matrix for Event ID 10952301
# Stored prediction matrix for Event ID 10952307
# Stored prediction matrix for Event ID 10952304
# Stored prediction matrix for Event ID 10952305
# Stored prediction matrix for Event ID 10952308
# Stored prediction matrix for Event ID 11067482
# Stored prediction matrix for Event ID 10952310
# Stored prediction matrix for Event ID 10952311
# Stored prediction matrix for Event ID 10952313
# Stored prediction matrix for Event ID 10952312
# Stored prediction matrix for Event ID 10952309
# Stored prediction matrix for Event ID 10952306
#
# Processing Week: 2023-21
# Skipping Event ID 10952298 due to uninitialized team(s)
# Skipping Event ID 10952292 due to uninitialized team(s)
# Skipping Event ID 10952289 due to uninitialized team(s)
# Skipping Event ID 10952286 due to uninitialized team(s)
# Skipping Event ID 10952290 due to uninitialized team(s)
# Skipping Event ID 10952291 due to uninitialized team(s)
# Skipping Event ID 10952295 due to uninitialized team(s)
# Skipping Event ID 10952300 due to uninitialized team(s)
# Skipping Event ID 10952294 due to uninitialized team(s)
# Skipping Event ID 10952296 due to uninitialized team(s)
# Skipping Event ID 10952297 due to uninitialized team(s)
# Skipping Event ID 10952299 due to uninitialized team(s)
# Skipping Event ID 10952293 due to uninitialized team(s)
# Skipping Event ID 11067532 due to uninitialized team(s)
# Skipping Event ID 11067528 due to uninitialized team(s)
# Skipping Event ID 11067524 due to uninitialized team(s)
# Skipping Event ID 10952287 due to uninitialized team(s)
# Skipping Event ID 11067530 due to uninitialized team(s)
# Skipping Event ID 10952284 due to uninitialized team(s)
# Skipping Event ID 10952276 due to uninitialized team(s)
# Skipping Event ID 11067518 due to uninitialized team(s)
# Skipping Event ID 11067511 due to uninitialized team(s)
# Skipping Event ID 11067526 due to uninitialized team(s)
# Skipping Event ID 11067522 due to uninitialized team(s)
# Skipping Event ID 10952272 due to uninitialized team(s)
# Skipping Event ID 10952275 due to uninitialized team(s)
# Skipping Event ID 10952279 due to uninitialized team(s)
# Skipping Event ID 10952282 due to uninitialized team(s)
# Skipping Event ID 10952278 due to uninitialized team(s)
# Skipping Event ID 10952283 due to uninitialized team(s)
# Skipping Event ID 11067520 due to uninitialized team(s)
# Skipping Event ID 10952281 due to uninitialized team(s)
# Skipping Event ID 10952285 due to uninitialized team(s)
# Skipping Event ID 10952280 due to uninitialized team(s)
# Skipping Event ID 10952277 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952298
# Stored prediction matrix for Event ID 10952292
# Stored prediction matrix for Event ID 10952289
# Stored prediction matrix for Event ID 10952286
# Stored prediction matrix for Event ID 10952290
# Stored prediction matrix for Event ID 10952291
# Stored prediction matrix for Event ID 10952295
# Stored prediction matrix for Event ID 10952300
# Stored prediction matrix for Event ID 10952294
# Stored prediction matrix for Event ID 10952296
# Stored prediction matrix for Event ID 10952297
# Stored prediction matrix for Event ID 10952299
# Stored prediction matrix for Event ID 10952293
# Stored prediction matrix for Event ID 11067532
# Stored prediction matrix for Event ID 11067528
# Stored prediction matrix for Event ID 11067524
# Stored prediction matrix for Event ID 10952287
# Stored prediction matrix for Event ID 11067530
# Stored prediction matrix for Event ID 10952284
# Stored prediction matrix for Event ID 10952276
# Stored prediction matrix for Event ID 11067518
# Stored prediction matrix for Event ID 11067511
# Stored prediction matrix for Event ID 11067526
# Stored prediction matrix for Event ID 11067522
# Stored prediction matrix for Event ID 10952272
# Stored prediction matrix for Event ID 10952275
# Stored prediction matrix for Event ID 10952279
# Stored prediction matrix for Event ID 10952282
# Stored prediction matrix for Event ID 10952278
# Stored prediction matrix for Event ID 10952283
# Stored prediction matrix for Event ID 11067520
# Stored prediction matrix for Event ID 10952281
# Stored prediction matrix for Event ID 10952285
# Stored prediction matrix for Event ID 10952280
# Stored prediction matrix for Event ID 10952277
#
# Processing Week: 2023-22
# Skipping Event ID 11067514 due to uninitialized team(s)
# Skipping Event ID 10952360 due to uninitialized team(s)
# Skipping Event ID 11308244 due to uninitialized team(s)
# Skipping Event ID 11284196 due to uninitialized team(s)
# Skipping Event ID 11067543 due to uninitialized team(s)
# Skipping Event ID 11067549 due to uninitialized team(s)
# Skipping Event ID 11067547 due to uninitialized team(s)
# Skipping Event ID 11067541 due to uninitialized team(s)
# Skipping Event ID 11067537 due to uninitialized team(s)
# Skipping Event ID 11067545 due to uninitialized team(s)
# Skipping Event ID 10952260 due to uninitialized team(s)
# Skipping Event ID 11067534 due to uninitialized team(s)
# Skipping Event ID 11067550 due to uninitialized team(s)
# Skipping Event ID 10952262 due to uninitialized team(s)
# Skipping Event ID 10952261 due to uninitialized team(s)
# Skipping Event ID 10952263 due to uninitialized team(s)
# Skipping Event ID 10952273 due to uninitialized team(s)
# Skipping Event ID 10952267 due to uninitialized team(s)
# Skipping Event ID 10952265 due to uninitialized team(s)
# Skipping Event ID 10952271 due to uninitialized team(s)
# Skipping Event ID 11067535 due to uninitialized team(s)
# Skipping Event ID 10952270 due to uninitialized team(s)
# Skipping Event ID 10952268 due to uninitialized team(s)
# Skipping Event ID 10952269 due to uninitialized team(s)
# Skipping Event ID 10952266 due to uninitialized team(s)
# Skipping Event ID 10952264 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067514
# Stored prediction matrix for Event ID 10952360
# Stored prediction matrix for Event ID 11308244
# Stored prediction matrix for Event ID 11284196
# Stored prediction matrix for Event ID 11067543
# Stored prediction matrix for Event ID 11067549
# Stored prediction matrix for Event ID 11067547
# Stored prediction matrix for Event ID 11067541
# Stored prediction matrix for Event ID 11067537
# Stored prediction matrix for Event ID 11067545
# Stored prediction matrix for Event ID 10952260
# Stored prediction matrix for Event ID 11067534
# Stored prediction matrix for Event ID 11067550
# Stored prediction matrix for Event ID 10952262
# Stored prediction matrix for Event ID 10952261
# Stored prediction matrix for Event ID 10952263
# Stored prediction matrix for Event ID 10952273
# Stored prediction matrix for Event ID 10952267
# Stored prediction matrix for Event ID 10952265
# Stored prediction matrix for Event ID 10952271
# Stored prediction matrix for Event ID 11067535
# Stored prediction matrix for Event ID 10952270
# Stored prediction matrix for Event ID 10952268
# Stored prediction matrix for Event ID 10952269
# Stored prediction matrix for Event ID 10952266
# Stored prediction matrix for Event ID 10952264
#
# Processing Week: 2023-23
# Skipping Event ID 10952259 due to uninitialized team(s)
# Skipping Event ID 11235843 due to uninitialized team(s)
# Skipping Event ID 10952258 due to uninitialized team(s)
# Skipping Event ID 10952254 due to uninitialized team(s)
# Skipping Event ID 10952255 due to uninitialized team(s)
# Skipping Event ID 10952256 due to uninitialized team(s)
# Skipping Event ID 10952253 due to uninitialized team(s)
# Skipping Event ID 10952257 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952259
# Stored prediction matrix for Event ID 11235843
# Stored prediction matrix for Event ID 10952258
# Stored prediction matrix for Event ID 10952254
# Stored prediction matrix for Event ID 10952255
# Stored prediction matrix for Event ID 10952256
# Stored prediction matrix for Event ID 10952253
# Stored prediction matrix for Event ID 10952257
#
# Processing Week: 2023-24
# Skipping Event ID 11067280 due to uninitialized team(s)
# Skipping Event ID 11067304 due to uninitialized team(s)
# Skipping Event ID 11067313 due to uninitialized team(s)
# Skipping Event ID 10952238 due to uninitialized team(s)
# Skipping Event ID 10952241 due to uninitialized team(s)
# Skipping Event ID 10952239 due to uninitialized team(s)
# Skipping Event ID 10952246 due to uninitialized team(s)
# Skipping Event ID 10952248 due to uninitialized team(s)
# Skipping Event ID 10952247 due to uninitialized team(s)
# Skipping Event ID 11067329 due to uninitialized team(s)
# Skipping Event ID 11067268 due to uninitialized team(s)
# Skipping Event ID 10952250 due to uninitialized team(s)
# Skipping Event ID 10952252 due to uninitialized team(s)
# Skipping Event ID 10952245 due to uninitialized team(s)
# Skipping Event ID 10952251 due to uninitialized team(s)
# Skipping Event ID 10952249 due to uninitialized team(s)
# Skipping Event ID 11067289 due to uninitialized team(s)
# Skipping Event ID 11067272 due to uninitialized team(s)
# Skipping Event ID 11067320 due to uninitialized team(s)
# Skipping Event ID 11067337 due to uninitialized team(s)
# Skipping Event ID 11067296 due to uninitialized team(s)
# Skipping Event ID 11067346 due to uninitialized team(s)
# Skipping Event ID 11067402 due to uninitialized team(s)
# Skipping Event ID 11067409 due to uninitialized team(s)
# Skipping Event ID 11067379 due to uninitialized team(s)
# Skipping Event ID 11067370 due to uninitialized team(s)
# Skipping Event ID 11067417 due to uninitialized team(s)
# Skipping Event ID 11067362 due to uninitialized team(s)
# Skipping Event ID 11067394 due to uninitialized team(s)
# Skipping Event ID 10952229 due to uninitialized team(s)
# Skipping Event ID 10952228 due to uninitialized team(s)
# Skipping Event ID 10952226 due to uninitialized team(s)
# Skipping Event ID 10952227 due to uninitialized team(s)
# Skipping Event ID 10952230 due to uninitialized team(s)
# Skipping Event ID 10952231 due to uninitialized team(s)
# Skipping Event ID 10952232 due to uninitialized team(s)
# Skipping Event ID 11067387 due to uninitialized team(s)
# Skipping Event ID 10952240 due to uninitialized team(s)
# Skipping Event ID 10952243 due to uninitialized team(s)
# Skipping Event ID 10952237 due to uninitialized team(s)
# Skipping Event ID 10952236 due to uninitialized team(s)
# Skipping Event ID 10952234 due to uninitialized team(s)
# Skipping Event ID 10952235 due to uninitialized team(s)
# Skipping Event ID 10952233 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067280
# Stored prediction matrix for Event ID 11067304
# Stored prediction matrix for Event ID 11067313
# Stored prediction matrix for Event ID 10952238
# Stored prediction matrix for Event ID 10952241
# Stored prediction matrix for Event ID 10952239
# Stored prediction matrix for Event ID 10952246
# Stored prediction matrix for Event ID 10952248
# Stored prediction matrix for Event ID 10952247
# Stored prediction matrix for Event ID 11067329
# Stored prediction matrix for Event ID 11067268
# Stored prediction matrix for Event ID 10952250
# Stored prediction matrix for Event ID 10952252
# Stored prediction matrix for Event ID 10952245
# Stored prediction matrix for Event ID 10952251
# Stored prediction matrix for Event ID 10952249
# Stored prediction matrix for Event ID 11067289
# Stored prediction matrix for Event ID 11067272
# Stored prediction matrix for Event ID 11067320
# Stored prediction matrix for Event ID 11067337
# Stored prediction matrix for Event ID 11067296
# Stored prediction matrix for Event ID 11067346
# Stored prediction matrix for Event ID 11067402
# Stored prediction matrix for Event ID 11067409
# Stored prediction matrix for Event ID 11067379
# Stored prediction matrix for Event ID 11067370
# Stored prediction matrix for Event ID 11067417
# Stored prediction matrix for Event ID 11067362
# Stored prediction matrix for Event ID 11067394
# Stored prediction matrix for Event ID 10952229
# Stored prediction matrix for Event ID 10952228
# Stored prediction matrix for Event ID 10952226
# Stored prediction matrix for Event ID 10952227
# Stored prediction matrix for Event ID 10952230
# Stored prediction matrix for Event ID 10952231
# Stored prediction matrix for Event ID 10952232
# Stored prediction matrix for Event ID 11067387
# Stored prediction matrix for Event ID 10952240
# Stored prediction matrix for Event ID 10952243
# Stored prediction matrix for Event ID 10952237
# Stored prediction matrix for Event ID 10952236
# Stored prediction matrix for Event ID 10952234
# Stored prediction matrix for Event ID 10952235
# Stored prediction matrix for Event ID 10952233
#
# Processing Week: 2023-25
# Skipping Event ID 11348996 due to uninitialized team(s)
# Skipping Event ID 11067353 due to uninitialized team(s)
# Skipping Event ID 11348995 due to uninitialized team(s)
# Skipping Event ID 11384724 due to uninitialized team(s)
# Skipping Event ID 11067440 due to uninitialized team(s)
# Skipping Event ID 11067488 due to uninitialized team(s)
# Skipping Event ID 11067424 due to uninitialized team(s)
# Skipping Event ID 11067431 due to uninitialized team(s)
# Skipping Event ID 11067497 due to uninitialized team(s)
# Skipping Event ID 10952209 due to uninitialized team(s)
# Skipping Event ID 11067480 due to uninitialized team(s)
# Skipping Event ID 11067463 due to uninitialized team(s)
# Skipping Event ID 10952212 due to uninitialized team(s)
# Skipping Event ID 10952215 due to uninitialized team(s)
# Skipping Event ID 10952214 due to uninitialized team(s)
# Skipping Event ID 10952217 due to uninitialized team(s)
# Skipping Event ID 11067448 due to uninitialized team(s)
# Skipping Event ID 10952216 due to uninitialized team(s)
# Skipping Event ID 10952218 due to uninitialized team(s)
# Skipping Event ID 11067472 due to uninitialized team(s)
# Skipping Event ID 10952224 due to uninitialized team(s)
# Skipping Event ID 10952219 due to uninitialized team(s)
# Skipping Event ID 10952222 due to uninitialized team(s)
# Skipping Event ID 10952221 due to uninitialized team(s)
# Skipping Event ID 10952223 due to uninitialized team(s)
# Skipping Event ID 10952225 due to uninitialized team(s)
# Skipping Event ID 10952220 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067353
# Stored prediction matrix for Event ID 11067440
# Stored prediction matrix for Event ID 11067488
# Stored prediction matrix for Event ID 11067424
# Stored prediction matrix for Event ID 11067431
# Stored prediction matrix for Event ID 11067497
# Stored prediction matrix for Event ID 10952209
# Stored prediction matrix for Event ID 11067480
# Stored prediction matrix for Event ID 11067463
# Stored prediction matrix for Event ID 10952212
# Stored prediction matrix for Event ID 10952215
# Stored prediction matrix for Event ID 10952214
# Stored prediction matrix for Event ID 10952217
# Stored prediction matrix for Event ID 11067448
# Stored prediction matrix for Event ID 10952216
# Stored prediction matrix for Event ID 10952218
# Stored prediction matrix for Event ID 11067472
# Stored prediction matrix for Event ID 10952224
# Stored prediction matrix for Event ID 10952219
# Stored prediction matrix for Event ID 10952222
# Stored prediction matrix for Event ID 10952221
# Stored prediction matrix for Event ID 10952223
# Stored prediction matrix for Event ID 10952225
# Stored prediction matrix for Event ID 10952220
#
# Processing Week: 2023-26
# Skipping Event ID 11067455 due to uninitialized team(s)
# Skipping Event ID 11084927 due to uninitialized team(s)
# Skipping Event ID 10952211 due to uninitialized team(s)
# Skipping Event ID 10952208 due to uninitialized team(s)
# Skipping Event ID 10952210 due to uninitialized team(s)
# Skipping Event ID 10952213 due to uninitialized team(s)
# Skipping Event ID 11067551 due to uninitialized team(s)
# Skipping Event ID 11067512 due to uninitialized team(s)
# Skipping Event ID 11067533 due to uninitialized team(s)
# Skipping Event ID 11067542 due to uninitialized team(s)
# Skipping Event ID 10952192 due to uninitialized team(s)
# Skipping Event ID 10952190 due to uninitialized team(s)
# Skipping Event ID 10952193 due to uninitialized team(s)
# Skipping Event ID 11067525 due to uninitialized team(s)
# Skipping Event ID 10952195 due to uninitialized team(s)
# Skipping Event ID 11067529 due to uninitialized team(s)
# Skipping Event ID 11067546 due to uninitialized team(s)
# Skipping Event ID 11067538 due to uninitialized team(s)
# Skipping Event ID 11067505 due to uninitialized team(s)
# Skipping Event ID 10952200 due to uninitialized team(s)
# Skipping Event ID 10952202 due to uninitialized team(s)
# Skipping Event ID 10952197 due to uninitialized team(s)
# Skipping Event ID 10952196 due to uninitialized team(s)
# Skipping Event ID 10952203 due to uninitialized team(s)
# Skipping Event ID 10952199 due to uninitialized team(s)
# Skipping Event ID 10952204 due to uninitialized team(s)
# Skipping Event ID 10952198 due to uninitialized team(s)
# Skipping Event ID 10952201 due to uninitialized team(s)
# Skipping Event ID 10952207 due to uninitialized team(s)
# Skipping Event ID 11067519 due to uninitialized team(s)
# Stored prediction matrix for Event ID 11067455
# Stored prediction matrix for Event ID 11084927
# Stored prediction matrix for Event ID 10952211
# Stored prediction matrix for Event ID 10952208
# Stored prediction matrix for Event ID 10952210
# Stored prediction matrix for Event ID 10952213
# Stored prediction matrix for Event ID 11067551
# Stored prediction matrix for Event ID 11067512
# Stored prediction matrix for Event ID 11067533
# Stored prediction matrix for Event ID 11067542
# Stored prediction matrix for Event ID 10952192
# Stored prediction matrix for Event ID 10952190
# Stored prediction matrix for Event ID 10952193
# Stored prediction matrix for Event ID 11067525
# Stored prediction matrix for Event ID 10952195
# Stored prediction matrix for Event ID 11067529
# Stored prediction matrix for Event ID 11067546
# Stored prediction matrix for Event ID 11067538
# Stored prediction matrix for Event ID 11067505
# Stored prediction matrix for Event ID 10952200
# Stored prediction matrix for Event ID 10952202
# Stored prediction matrix for Event ID 10952197
# Stored prediction matrix for Event ID 10952196
# Stored prediction matrix for Event ID 10952203
# Stored prediction matrix for Event ID 10952199
# Stored prediction matrix for Event ID 10952204
# Stored prediction matrix for Event ID 10952198
# Stored prediction matrix for Event ID 10952201
# Stored prediction matrix for Event ID 10952207
# Stored prediction matrix for Event ID 11067519
#
# Processing Week: 2023-27
# Skipping Event ID 11362863 due to uninitialized team(s)
# Skipping Event ID 11362842 due to uninitialized team(s)
# Skipping Event ID 11362846 due to uninitialized team(s)
# Skipping Event ID 11362844 due to uninitialized team(s)
# Skipping Event ID 11362865 due to uninitialized team(s)
# Skipping Event ID 11362843 due to uninitialized team(s)
# Skipping Event ID 11362845 due to uninitialized team(s)
# Skipping Event ID 11362841 due to uninitialized team(s)
# Skipping Event ID 11404325 due to uninitialized team(s)
# Skipping Event ID 11362877 due to uninitialized team(s)
# Skipping Event ID 11362839 due to uninitialized team(s)
# Skipping Event ID 11362861 due to uninitialized team(s)
# Skipping Event ID 11362848 due to uninitialized team(s)
# Skipping Event ID 11362840 due to uninitialized team(s)
# Skipping Event ID 11362875 due to uninitialized team(s)
# Skipping Event ID 10952189 due to uninitialized team(s)
# Skipping Event ID 10952191 due to uninitialized team(s)
# Skipping Event ID 10952187 due to uninitialized team(s)
# Skipping Event ID 10952188 due to uninitialized team(s)
# Skipping Event ID 10952184 due to uninitialized team(s)
# Skipping Event ID 10952206 due to uninitialized team(s)
# Skipping Event ID 11274089 due to uninitialized team(s)
# Skipping Event ID 10952185 due to uninitialized team(s)
# Skipping Event ID 10952186 due to uninitialized team(s)
# Skipping Event ID 10952194 due to uninitialized team(s)
# Skipping Event ID 10952170 due to uninitialized team(s)
# Skipping Event ID 10952171 due to uninitialized team(s)
# Skipping Event ID 11067563 due to uninitialized team(s)
# Skipping Event ID 11067569 due to uninitialized team(s)
# Skipping Event ID 10952172 due to uninitialized team(s)
# Skipping Event ID 11067553 due to uninitialized team(s)
# Skipping Event ID 11067565 due to uninitialized team(s)
# Skipping Event ID 10952173 due to uninitialized team(s)
# Skipping Event ID 11067567 due to uninitialized team(s)
# Skipping Event ID 11067557 due to uninitialized team(s)
# Skipping Event ID 10952180 due to uninitialized team(s)
# Skipping Event ID 10952177 due to uninitialized team(s)
# Skipping Event ID 10952181 due to uninitialized team(s)
# Skipping Event ID 10952183 due to uninitialized team(s)
# Skipping Event ID 10952174 due to uninitialized team(s)
# Skipping Event ID 11067555 due to uninitialized team(s)
# Skipping Event ID 10952178 due to uninitialized team(s)
# Skipping Event ID 10952175 due to uninitialized team(s)
# Skipping Event ID 10952182 due to uninitialized team(s)
# Skipping Event ID 10952179 due to uninitialized team(s)
# Skipping Event ID 10952176 due to uninitialized team(s)
# Stored prediction matrix for Event ID 10952189
# Stored prediction matrix for Event ID 10952191
# ...
# Stored prediction matrix for Event ID 12468880
# Stored prediction matrix for Event ID 12468884
# Stored prediction matrix for Event ID 12468865
# Stored prediction matrix for Event ID 12437057
# Stored prediction matrix for Event ID 12437054
# Stored prediction matrix for Event ID 12499757
# Stored prediction matrix for Event ID 12504706
# Stored prediction matrix for Event ID 12437655
# Stored prediction matrix for Event ID 12514059
# Stored prediction matrix for Event ID 12451065
# Stored prediction matrix for Event ID 13010891
# Stored prediction matrix for Event ID 12437634
# Stored prediction matrix for Event ID 12514066
# Stored prediction matrix for Event ID 13010892
# Stored prediction matrix for Event ID 12437055
# Stored prediction matrix for Event ID 12504702
# Stored prediction matrix for Event ID 12499767
# Stored prediction matrix for Event ID 12514060
# Stored prediction matrix for Event ID 12451063
# Stored prediction matrix for Event ID 12514061
# Stored prediction matrix for Event ID 12437658
# Stored prediction matrix for Event ID 12468875
# Stored prediction matrix for Event ID 12499760
# Stored prediction matrix for Event ID 12451060
# Stored prediction matrix for Event ID 12504700
# Stored prediction matrix for Event ID 12451061
# Stored prediction matrix for Event ID 12437059
# Stored prediction matrix for Event ID 12437637
# Stored prediction matrix for Event ID 12504704
# Stored prediction matrix for Event ID 13010886
#
# Processing Week: 2024-44
# Skipping Event ID 12117289 due to uninitialized team(s)
# Skipping Event ID 12514068 due to uninitialized team(s)
# Skipping Event ID 12437639 due to uninitialized team(s)
# Skipping Event ID 12437052 due to uninitialized team(s)
# Skipping Event ID 12499360 due to uninitialized team(s)
# Skipping Event ID 12504699 due to uninitialized team(s)
# Skipping Event ID 13022415 due to uninitialized team(s)
# Skipping Event ID 12504698 due to uninitialized team(s)
# Skipping Event ID 12764155 due to uninitialized team(s)
# Skipping Event ID 12764432 due to uninitialized team(s)
# Skipping Event ID 12764498 due to uninitialized team(s)
# Skipping Event ID 12764139 due to uninitialized team(s)
# Skipping Event ID 12764316 due to uninitialized team(s)
# Skipping Event ID 12764301 due to uninitialized team(s)
# Skipping Event ID 12764172 due to uninitialized team(s)
# Skipping Event ID 12764396 due to uninitialized team(s)
# Skipping Event ID 12468853 due to uninitialized team(s)
# Skipping Event ID 12468851 due to uninitialized team(s)
# Skipping Event ID 12468860 due to uninitialized team(s)
# Skipping Event ID 12468852 due to uninitialized team(s)
# Skipping Event ID 12468856 due to uninitialized team(s)
# Skipping Event ID 12764474 due to uninitialized team(s)
# Skipping Event ID 12468846 due to uninitialized team(s)
# Skipping Event ID 12764375 due to uninitialized team(s)
# Skipping Event ID 12468838 due to uninitialized team(s)
# Skipping Event ID 12764236 due to uninitialized team(s)
# Skipping Event ID 12764482 due to uninitialized team(s)
# Skipping Event ID 12468836 due to uninitialized team(s)
# Skipping Event ID 12764513 due to uninitialized team(s)
# Skipping Event ID 12764209 due to uninitialized team(s)
# Skipping Event ID 12764263 due to uninitialized team(s)
# Skipping Event ID 12764064 due to uninitialized team(s)
# Skipping Event ID 12117284 due to uninitialized team(s)
# Skipping Event ID 12468842 due to uninitialized team(s)
# Skipping Event ID 12468858 due to uninitialized team(s)
# Skipping Event ID 12764191 due to uninitialized team(s)
# Skipping Event ID 12764468 due to uninitialized team(s)
# Skipping Event ID 12764315 due to uninitialized team(s)
# Skipping Event ID 12117288 due to uninitialized team(s)
# Skipping Event ID 12468840 due to uninitialized team(s)
# Skipping Event ID 12117286 due to uninitialized team(s)
# Skipping Event ID 12117292 due to uninitialized team(s)
# Skipping Event ID 12117285 due to uninitialized team(s)
# Skipping Event ID 12437680 due to uninitialized team(s)
# Skipping Event ID 12504694 due to uninitialized team(s)
# Skipping Event ID 12468811 due to uninitialized team(s)
# Skipping Event ID 12499794 due to uninitialized team(s)
# Skipping Event ID 12451071 due to uninitialized team(s)
# Skipping Event ID 12117294 due to uninitialized team(s)
# Skipping Event ID 12514077 due to uninitialized team(s)
# Skipping Event ID 12514077 due to uninitialized team(s)
# Skipping Event ID 12117294 due to uninitialized team(s)
# Skipping Event ID 12499794 due to uninitialized team(s)
# Skipping Event ID 12451071 due to uninitialized team(s)
# Skipping Event ID 12468811 due to uninitialized team(s)
# Skipping Event ID 12437680 due to uninitialized team(s)
# Skipping Event ID 12504694 due to uninitialized team(s)
# Skipping Event ID 12499777 due to uninitialized team(s)
# Skipping Event ID 12499797 due to uninitialized team(s)
# Skipping Event ID 12499783 due to uninitialized team(s)
# Skipping Event ID 12499802 due to uninitialized team(s)
# Skipping Event ID 12499791 due to uninitialized team(s)
# Skipping Event ID 12468812 due to uninitialized team(s)
# Skipping Event ID 12504692 due to uninitialized team(s)
# Skipping Event ID 13080190 due to uninitialized team(s)
# Skipping Event ID 12504701 due to uninitialized team(s)
# Skipping Event ID 12504688 due to uninitialized team(s)
# Skipping Event ID 12468825 due to uninitialized team(s)
# Skipping Event ID 12437666 due to uninitialized team(s)
# Skipping Event ID 12437682 due to uninitialized team(s)
# Skipping Event ID 12437678 due to uninitialized team(s)
# Skipping Event ID 12436882 due to uninitialized team(s)
# Skipping Event ID 12436484 due to uninitialized team(s)
# Skipping Event ID 12468831 due to uninitialized team(s)
# Skipping Event ID 12468820 due to uninitialized team(s)
# Skipping Event ID 12451076 due to uninitialized team(s)
# Skipping Event ID 12468833 due to uninitialized team(s)
# Skipping Event ID 12117303 due to uninitialized team(s)
# Skipping Event ID 12117301 due to uninitialized team(s)
# Skipping Event ID 13065688 due to uninitialized team(s)
# Skipping Event ID 12117295 due to uninitialized team(s)
# Skipping Event ID 12117302 due to uninitialized team(s)
# Skipping Event ID 12117296 due to uninitialized team(s)
# Skipping Event ID 12117298 due to uninitialized team(s)
# Skipping Event ID 12117299 due to uninitialized team(s)
# Skipping Event ID 13062285 due to uninitialized team(s)
# Skipping Event ID 12514072 due to uninitialized team(s)
# Skipping Event ID 12514076 due to uninitialized team(s)
# Skipping Event ID 12514079 due to uninitialized team(s)
# Skipping Event ID 12514073 due to uninitialized team(s)
# Skipping Event ID 12468818 due to uninitialized team(s)
# Skipping Event ID 12451079 due to uninitialized team(s)
# Skipping Event ID 12451075 due to uninitialized team(s)
# Skipping Event ID 12436485 due to uninitialized team(s)
# Skipping Event ID 12436484 due to uninitialized team(s)
# Skipping Event ID 12436483 due to uninitialized team(s)
# Skipping Event ID 12451076 due to uninitialized team(s)
# Skipping Event ID 12451075 due to uninitialized team(s)
# Skipping Event ID 12499777 due to uninitialized team(s)
# Skipping Event ID 12499797 due to uninitialized team(s)
# Skipping Event ID 12499783 due to uninitialized team(s)
# Skipping Event ID 12499802 due to uninitialized team(s)
# Skipping Event ID 12499791 due to uninitialized team(s)
# Skipping Event ID 12504692 due to uninitialized team(s)
# Skipping Event ID 12504701 due to uninitialized team(s)
# Skipping Event ID 12504688 due to uninitialized team(s)
# Skipping Event ID 12437666 due to uninitialized team(s)
# Skipping Event ID 12437682 due to uninitialized team(s)
# Skipping Event ID 12437678 due to uninitialized team(s)
# Skipping Event ID 12436882 due to uninitialized team(s)
# Skipping Event ID 12436485 due to uninitialized team(s)
# Skipping Event ID 12436486 due to uninitialized team(s)
# Skipping Event ID 12436483 due to uninitialized team(s)
# Skipping Event ID 12436876 due to uninitialized team(s)
# Skipping Event ID 12468821 due to uninitialized team(s)
# Skipping Event ID 12451079 due to uninitialized team(s)
# Skipping Event ID 12514073 due to uninitialized team(s)
# Skipping Event ID 12514079 due to uninitialized team(s)
# Skipping Event ID 12514076 due to uninitialized team(s)
# Skipping Event ID 12436876 due to uninitialized team(s)
# Skipping Event ID 12468814 due to uninitialized team(s)
# Skipping Event ID 12468821 due to uninitialized team(s)
# Skipping Event ID 12468818 due to uninitialized team(s)
# Skipping Event ID 12468825 due to uninitialized team(s)
# Skipping Event ID 12468831 due to uninitialized team(s)
# Skipping Event ID 12468812 due to uninitialized team(s)
# Skipping Event ID 12468820 due to uninitialized team(s)
# Skipping Event ID 12468833 due to uninitialized team(s)
# Skipping Event ID 12436486 due to uninitialized team(s)
# Skipping Event ID 13062285 due to uninitialized team(s)
# Skipping Event ID 13080190 due to uninitialized team(s)
# Skipping Event ID 12117303 due to uninitialized team(s)
# Skipping Event ID 12117301 due to uninitialized team(s)
# Skipping Event ID 12117295 due to uninitialized team(s)
# Skipping Event ID 12117302 due to uninitialized team(s)
# Skipping Event ID 12117296 due to uninitialized team(s)
# Skipping Event ID 12117298 due to uninitialized team(s)
# Skipping Event ID 12117299 due to uninitialized team(s)
# Skipping Event ID 12514072 due to uninitialized team(s)
# Skipping Event ID 13065688 due to uninitialized team(s)
# Skipping Event ID 12468814 due to uninitialized team(s)
# Stored prediction matrix for Event ID 12117289
# Stored prediction matrix for Event ID 12514068
# Stored prediction matrix for Event ID 12437639
# Stored prediction matrix for Event ID 12437052
# Stored prediction matrix for Event ID 12499360
# Stored prediction matrix for Event ID 12504699
# Stored prediction matrix for Event ID 13022415
# Stored prediction matrix for Event ID 12504698
# Stored prediction matrix for Event ID 12764155
# Stored prediction matrix for Event ID 12764432
# Stored prediction matrix for Event ID 12764498
# Stored prediction matrix for Event ID 12764139
# Stored prediction matrix for Event ID 12764316
# Stored prediction matrix for Event ID 12764301
# Stored prediction matrix for Event ID 12764172
# Stored prediction matrix for Event ID 12764396
# Stored prediction matrix for Event ID 12468853
# Stored prediction matrix for Event ID 12468851
# Stored prediction matrix for Event ID 12468860
# Stored prediction matrix for Event ID 12468852
# Stored prediction matrix for Event ID 12468856
# Stored prediction matrix for Event ID 12764474
# Stored prediction matrix for Event ID 12468846
# Stored prediction matrix for Event ID 12764375
# Stored prediction matrix for Event ID 12468838
# Stored prediction matrix for Event ID 12764236
# Stored prediction matrix for Event ID 12764482
# Stored prediction matrix for Event ID 12468836
# Stored prediction matrix for Event ID 12764513
# Stored prediction matrix for Event ID 12764209
# Stored prediction matrix for Event ID 12764263
# Stored prediction matrix for Event ID 12764064
# Stored prediction matrix for Event ID 12117284
# Stored prediction matrix for Event ID 12468842
# Stored prediction matrix for Event ID 12468858
# Stored prediction matrix for Event ID 12764191
# Stored prediction matrix for Event ID 12764468
# Stored prediction matrix for Event ID 12764315
# Stored prediction matrix for Event ID 12117288
# Stored prediction matrix for Event ID 12468840
# Stored prediction matrix for Event ID 12117286
# Stored prediction matrix for Event ID 12117292
# Stored prediction matrix for Event ID 12117285
# Stored prediction matrix for Event ID 12437680
# Stored prediction matrix for Event ID 12504694
# Stored prediction matrix for Event ID 12468811
# Stored prediction matrix for Event ID 12499794
# Stored prediction matrix for Event ID 12451071
# Stored prediction matrix for Event ID 12117294
# Stored prediction matrix for Event ID 12514077
# Stored prediction matrix for Event ID 12514077
# Stored prediction matrix for Event ID 12117294
# Stored prediction matrix for Event ID 12499794
# Stored prediction matrix for Event ID 12451071
# Stored prediction matrix for Event ID 12468811
# Stored prediction matrix for Event ID 12437680
# Stored prediction matrix for Event ID 12504694
# Stored prediction matrix for Event ID 12499777
# Stored prediction matrix for Event ID 12499797
# Stored prediction matrix for Event ID 12499783
# Stored prediction matrix for Event ID 12499802
# Stored prediction matrix for Event ID 12499791
# Stored prediction matrix for Event ID 12468812
# Stored prediction matrix for Event ID 12504692
# Stored prediction matrix for Event ID 13080190
# Stored prediction matrix for Event ID 12504701
# Stored prediction matrix for Event ID 12504688
# Stored prediction matrix for Event ID 12468825
# Stored prediction matrix for Event ID 12437666
# Stored prediction matrix for Event ID 12437682
# Stored prediction matrix for Event ID 12437678
# Stored prediction matrix for Event ID 12436882
# Stored prediction matrix for Event ID 12436484
# Stored prediction matrix for Event ID 12468831
# Stored prediction matrix for Event ID 12468820
# Stored prediction matrix for Event ID 12451076
# Stored prediction matrix for Event ID 12468833
# Stored prediction matrix for Event ID 12117303
# Stored prediction matrix for Event ID 12117301
# Stored prediction matrix for Event ID 13065688
# Stored prediction matrix for Event ID 12117295
# Stored prediction matrix for Event ID 12117302
# Stored prediction matrix for Event ID 12117296
# Stored prediction matrix for Event ID 12117298
# Stored prediction matrix for Event ID 12117299
# Stored prediction matrix for Event ID 13062285
# Stored prediction matrix for Event ID 12514072
# Stored prediction matrix for Event ID 12514076
# Stored prediction matrix for Event ID 12514079
# Stored prediction matrix for Event ID 12514073
# Stored prediction matrix for Event ID 12468818
# Stored prediction matrix for Event ID 12451079
# Stored prediction matrix for Event ID 12451075
# Stored prediction matrix for Event ID 12436485
# Stored prediction matrix for Event ID 12436484
# Stored prediction matrix for Event ID 12436483
# Stored prediction matrix for Event ID 12451076
# Stored prediction matrix for Event ID 12451075
# Stored prediction matrix for Event ID 12499777
# Stored prediction matrix for Event ID 12499797
# Stored prediction matrix for Event ID 12499783
# Stored prediction matrix for Event ID 12499802
# Stored prediction matrix for Event ID 12499791
# Stored prediction matrix for Event ID 12504692
# Stored prediction matrix for Event ID 12504701
# Stored prediction matrix for Event ID 12504688
# Stored prediction matrix for Event ID 12437666
# Stored prediction matrix for Event ID 12437682
# Stored prediction matrix for Event ID 12437678
# Stored prediction matrix for Event ID 12436882
# Stored prediction matrix for Event ID 12436485
# Stored prediction matrix for Event ID 12436486
# Stored prediction matrix for Event ID 12436483
# Stored prediction matrix for Event ID 12436876
# Stored prediction matrix for Event ID 12468821
# Stored prediction matrix for Event ID 12451079
# Stored prediction matrix for Event ID 12514073
# Stored prediction matrix for Event ID 12514079
# Stored prediction matrix for Event ID 12514076
# Stored prediction matrix for Event ID 12436876
# Stored prediction matrix for Event ID 12468814
# Stored prediction matrix for Event ID 12468821
# Stored prediction matrix for Event ID 12468818
# Stored prediction matrix for Event ID 12468825
# Stored prediction matrix for Event ID 12468831
# Stored prediction matrix for Event ID 12468812
# Stored prediction matrix for Event ID 12468820
# Stored prediction matrix for Event ID 12468833
# Stored prediction matrix for Event ID 12436486
# Stored prediction matrix for Event ID 13062285
# Stored prediction matrix for Event ID 13080190
# Stored prediction matrix for Event ID 12117303
# Stored prediction matrix for Event ID 12117301
# Stored prediction matrix for Event ID 12117295
# Stored prediction matrix for Event ID 12117302
# Stored prediction matrix for Event ID 12117296
# Stored prediction matrix for Event ID 12117298
# Stored prediction matrix for Event ID 12117299
# Stored prediction matrix for Event ID 12514072
# Stored prediction matrix for Event ID 13065688
# Stored prediction matrix for Event ID 12468814

# %%
params

# %%
predict(params, "Chelsea", "Arsenal")
# predict_ST(sot_params, "Bayern Munich", "Benfica")
#predict(params, "PSV Eindhoven", "Girona")
# predict(params, "Lille", "Juventus")
# predict(params, "Lille", "Juventus")
# # predict(params, "Lille", "Juventus")
# predict_(params, "Celtic", "RB Leipzig")
# dc_sot.predict_shots_on_target("Celtic", "RB Leipzig")

# %%
def calculate_o25_probability_independent(row, model_params):
    home_team = row['homeTeam']
    away_team = row['awayTeam']
    
    home_attack = params["attack_" + home_team]
    home_defence = params["defence_" + home_team]
    away_attack = params["attack_" + away_team]
    away_defence = params["defence_" + away_team]
    home_advantage = params["home_advantage"]
    rho = params["rho"]

    # Calculate expected goals using exponential to ensure positivity
    home_goal_expectation = np.exp(home_attack + away_defence + home_advantage)
    away_goal_expectation = np.exp(away_attack + home_defence)

    # Poisson probabilities for goals from 0 to 5
    max_goals = 5
    goal_range = np.arange(0, max_goals + 1)
    home_probs = poisson.pmf(goal_range, home_goal_expectation)
    away_probs = poisson.pmf(goal_range, away_goal_expectation)

    # Goal probability matrix (Home Goals x Away Goals)
    m = np.outer(home_probs, away_probs)
    
    # Adjust for correlation (if rho is used in your model)
    if rho != 0:
        m[0, 0] *= 1 - home_goal_expectation * away_goal_expectation * rho
        m[0, 1] *= 1 + home_goal_expectation * rho
        m[1, 0] *= 1 + away_goal_expectation * rho
        m[1, 1] *= 1 - rho    
        
    max_total_goals = 2 * max_goals  # Maximum possible total goals
    total_goals_probs = np.zeros(max_total_goals + 1)
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            total_goals = i + j
            total_goals_probs[total_goals] += m[i, j]
            
    under_prob = np.sum(total_goals_probs[:3]) 
    over_prob = 1 - under_prob 
    return over_prob

# %%
test['O25_Prob'] = test.apply(lambda row: calculate_o25_probability_independent(row, params), axis=1)
test['O25_Prob']

# %%
o25_threshold = 0.6
# Independent Poisson Backtesting
high_o25_matches = test[test['O25_Prob'] > o25_threshold]
high_o25_matches['Actual_O25'] = (high_o25_matches['homeScore'] + high_o25_matches['awayScore']) > 2

# %%
num_predictions = len(high_o25_matches)
num_correct = high_o25_matches['Actual_O25'].sum()
success_rate = num_correct / num_predictions if num_predictions > 0 else 0

print(f"\nTotal Predictions (O2.5 Prob > {o25_threshold}): {num_predictions}")
print(f"Correct Predictions (Over 2.5 Goals): {num_correct}")
print(f"Success Rate: {success_rate:.2%}")
high_o25_matches[['O25_Prob','Actual_O25','homeTeam','homeScore','awayTeam','awayScore']]

# %%
def calculate_u25_probability_independent(row, model_params):
    home_team = row['homeTeam']
    away_team = row['awayTeam']
    
    # Extract model parameters
    attack_home = model_params["attack_" + home_team]
    defence_home = model_params["defence_" + home_team]
    attack_away = model_params["attack_" + away_team]
    defence_away = model_params["defence_" + away_team]
    home_advantage = model_params["home_advantage"]
    
    # Calculate expected goals
    lambda_home = np.exp(attack_home + defence_away + home_advantage)
    lambda_away = np.exp(attack_away + defence_home)
    
    # Sum Poisson parameters
    lambda_total = lambda_home + lambda_away
    
    # Probability of total goals <=2
    p_total_leq_2 = poisson.cdf(2, lambda_total)
    
    # Return probability of under 2.5 goals
    return p_total_leq_2

# %%
test['U25_Prob'] = test.apply(lambda row: calculate_u25_probability_independent(row, params), axis=1)
test['U25_Prob']

# %%
o25_threshold = 0.65
# Independent Poisson Backtesting
high_o25_matches = test[test['U25_Prob'] > o25_threshold]
high_o25_matches['Actual_U25'] = (high_o25_matches['homeScore'] + high_o25_matches['awayScore']) <= 2

# %%
num_predictions = len(high_o25_matches)
num_correct = high_o25_matches['Actual_U25'].sum()
success_rate = num_correct / num_predictions if num_predictions > 0 else 0

print(f"\nTotal Predictions (U2.5 Prob > {o25_threshold}): {num_predictions}")
print(f"Correct Predictions (Under 2.5 Goals): {num_correct}")
print(f"Success Rate: {success_rate:.2%}")
high_o25_matches[['U25_Prob','Actual_U25','homeScore','awayScore']]

# %%
def evaluate_model(matches_df, params, confidence_threshold=0.5):
    correct_predictions = 0
    total_matches = 0  # Count of matches considered with confidence above the threshold
    threshold_hits = 0  # Count of times the confidence threshold was met
    
    # For Log Loss
    log_loss = 0
    epsilon = 1e-15  # To prevent log(0)
    
    for index, row in matches_df.iterrows():
        home_team = row['homeTeam']
        away_team = row['awayTeam']
        actual_home_shots = row['homeScore']
        actual_away_shots = row['awayScore']
        
        # Get predicted probabilities
        home_prob, draw_prob, away_prob, _, _, _ ,_= predict(params, home_team, away_team)
        
        # Get the maximum probability for the predicted outcome
        max_prob = max(home_prob, draw_prob, away_prob)
        
        
        # Only consider predictions with confidence above the threshold
        if max_prob >= confidence_threshold:
            threshold_hits += 1  # Increment the threshold hit count
            total_matches += 1
            
            # Determine predicted outcome based on highest probability
            if home_prob == max_prob:
                predicted_outcome = 'Home'
            elif away_prob == max_prob:
                predicted_outcome = 'Away'
            else:
                predicted_outcome = 'Draw'
            
            # Determine actual outcome
            if actual_home_shots > actual_away_shots:
                actual_outcome = 'Home'
            elif actual_away_shots > actual_home_shots:
                actual_outcome = 'Away'
            else:
                actual_outcome = 'Draw'
            
            # Check if prediction is correct
            if predicted_outcome == actual_outcome:
                correct_predictions += 1
            
            # Update Log Loss based on the actual outcome
            if actual_outcome == 'Home':
                log_loss += -np.log(home_prob + epsilon)
            elif actual_outcome == 'Draw':
                log_loss += -np.log(draw_prob + epsilon)
            else:
                log_loss += -np.log(away_prob + epsilon)
    
    # Calculate Metrics
    if total_matches > 0:
        accuracy = correct_predictions / total_matches
        average_log_loss = log_loss / total_matches
        print(f"Accuracy (for confidence >= {confidence_threshold}): {accuracy:.2%}")
        print(f"Average Log Loss (for confidence >= {confidence_threshold}): {average_log_loss:.4f}")
    else:
        print(f"No predictions met the confidence threshold of {confidence_threshold}")
        accuracy = None
        average_log_loss = None
    
    print(f"Threshold hits (confidence >= {confidence_threshold}): {threshold_hits}")
    
    return accuracy, average_log_loss, threshold_hits

# Example usage:
# matches_df = pd.read_csv('historical_matches.csv')  # Ensure your CSV has the required columns
# evaluate_model(matches_df, params, confidence_threshold=0.7)

# %%
test = df.iloc[-466:]

# %%
evaluate_model(test,params,0.70)

# %%
def evaluate_over_under(matches_df, params, thresholds):
    # Initialize a dictionary to store results for each threshold
    results = {threshold: {'correct_predictions': 0, 'total_predictions': 0} for threshold in thresholds}
    
    for index, row in matches_df.iterrows():
        home_team = row['HomeTeam']
        away_team = row['AwayTeam']
        actual_total_goals = row['FTHG'] + row['FTAG']
        
        # Get predicted probabilities
        _, _, _, over_under_total_results, _, _ = predict(params, home_team, away_team)
        
        # Get the probability for Over 2.5 Goals
        over_2_5_prob = over_under_total_results[2.5]['Over']
        
        # Iterate over each confidence threshold
        for threshold in thresholds:
            if over_2_5_prob >= threshold:
                results[threshold]['total_predictions'] += 1
                predicted_outcome = 'Over'
                
                # Determine actual outcome
                actual_outcome = 'Over' if actual_total_goals > 2.5 else 'Under'
                
                # Check if prediction is correct
                if predicted_outcome == actual_outcome:
                    results[threshold]['correct_predictions'] += 1
    
    # Calculate and print results for each threshold
    for threshold in thresholds:
        total = results[threshold]['total_predictions']
        correct = results[threshold]['correct_predictions']
        if total > 0:
            accuracy = correct / total
            print(f"\nConfidence Threshold >= {threshold}:")
            print(f"Total Predictions Made: {total}")
            print(f"Correct Predictions: {correct}")
            print(f"Accuracy: {accuracy:.2%}")
        else:
            print(f"\nConfidence Threshold >= {threshold}: No predictions made.")
    
    return results

# Example usage:
# Define your confidence thresholds
confidence_thresholds = [0.5,0.6,0.7]

# Assuming you have a DataFrame 'matches_df' with the necessary columns
# matches_df = pd.read_csv('historical_matches.csv')  # Ensure your CSV has 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG'

# Call the evaluation function
results = evaluate_over_under(test, params, confidence_thresholds)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def predict(params, home_team, away_team):
    home_attack = params["attack_" + home_team]
    home_defence = params["defence_" + home_team]
    away_attack = params["attack_" + away_team]
    away_defence = params["defence_" + away_team]
    home_advantage = params["home_advantage"]
    rho = params["rho"]

    # Calculate expected goals using exponential to ensure positivity
    home_goal_expectation = np.exp(home_attack + away_defence + home_advantage)
    away_goal_expectation = np.exp(away_attack + home_defence)

    # Poisson probabilities for goals from 0 to 9
    max_goals = 9
    goal_range = np.arange(0, max_goals + 1)
    home_probs = poisson.pmf(goal_range, home_goal_expectation)
    away_probs = poisson.pmf(goal_range, away_goal_expectation)

    # Goal probability matrix (Home Goals x Away Goals)
    m = np.outer(home_probs, away_probs)
    
    # Adjust for correlation (if rho is used in your model)
    if rho != 0:
        m[0, 0] *= 1 - home_goal_expectation * away_goal_expectation * rho
        m[0, 1] *= 1 + home_goal_expectation * rho
        m[1, 0] *= 1 + away_goal_expectation * rho
        m[1, 1] *= 1 - rho    
    
    # Ensure the matrix sums to 1 after adjustments
    m = m / m.sum()
    # print(home_probs)
    # # Calculate both teams to score (BTTS) probability
    p_home_zero = home_probs[0]       # P(Home = 0)
    p_away_zero = away_probs[0]       # P(Away = 0)
    p_both_score = 1 - (p_home_zero + p_away_zero - m[0, 0])
    # print(f'{home_team} VS {away_team} Cheat Sheet')
    # print('============================================================')
    # print(f'Both Teams To Score (BTTS) Probability: {p_both_score:.4f}')
    # print(f'BTTS Odds: {1/p_both_score:.4f}')

    # # Optional: Plotting the goal probability matrix
    
    # plt.figure(figsize=(8, 6))
    # plt.imshow(m, cmap='Blues', interpolation='nearest')
    # plt.colorbar(label='Probability')
    # plt.xlabel("Away Goals")
    # plt.ylabel("Home Goals")
    # plt.title("Goal Probability Matrix (m)")

    # Display the values in each cell
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            plt.text(j, i, f"{m[i, j]:.2f}", ha='center', va='center', color="black")

    # plt.show()
    

    # Calculate match outcome probabilities
    home_win_prob = np.sum(np.tril(m, -1))
    draw_prob = np.sum(np.diag(m))
    away_win_prob = np.sum(np.triu(m, 1))

    # Display probabilities for match outcomes
    # print("\nMatch Outcome Probabilities:")
    # print(f"Home Win Probability: {home_win_prob:.4f}")
    # print(f"Draw Probability: {draw_prob:.4f}")
    # print(f"Away Win Probability: {away_win_prob:.4f}")

    # Calculate total goals probabilities
    max_total_goals = 2 * max_goals  # Maximum possible total goals
    total_goals_probs = np.zeros(max_total_goals + 1)
    for i in range(m.shape[0]):
        for j in range(m.shape[1]):
            total_goals = i + j
            total_goals_probs[total_goals] += m[i, j]

    # Calculate over/under probabilities for total goals
    def over_under_total_prob(threshold):
        under_prob = np.sum(total_goals_probs[:int(np.floor(threshold)) + 1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    total_thresholds = [1.5, 2.5, 3.5]
    over_under_total_results = {}
    for threshold in total_thresholds:
        under_prob, over_prob = over_under_total_prob(threshold)
        over_under_total_results[threshold] = {
            'Under': under_prob,
            'Over': over_prob
        }
        # print(f"Under {threshold} total goals: {under_prob:.4f}, Over {threshold} total goals: {over_prob:.4f}")

    # Calculate over/under probabilities for individual team goals
    def over_under_team_prob(probs, threshold):
        # Under probability: P(goals <= floor(threshold))
        under_prob = np.sum(probs[:int(np.floor(threshold)) + 1])
        over_prob = 1 - under_prob
        return under_prob, over_prob

    team_thresholds = [0.5, 1.5, 2.5, 3.5]
    over_under_team_results = {home_team: {}, away_team: {}}

    for threshold in team_thresholds:
        # Home team over/under
        under_prob_home, over_prob_home = over_under_team_prob(home_probs, threshold)
        over_under_team_results[home_team][threshold] = {
            'Under': under_prob_home,
            'Over': over_prob_home
        }

        # Away team over/under
        under_prob_away, over_prob_away = over_under_team_prob(away_probs, threshold)
        over_under_team_results[away_team][threshold] = {
            'Under': under_prob_away,
            'Over': over_prob_away
        }

    # Calculate probabilities for goal ranges
    goal_ranges = {
        '0-2 Goals': (0, 2),
        '1-3 Goals': (1, 3),
        '1-4 Goals': (1, 4),
        '2-3 Goals': (2, 3),
        '2-4 Goals': (2, 4),
        '4+ Goals': (4, max_total_goals)
    }

    goal_range_probs = {}
    for range_name, (start, end) in goal_ranges.items():
        # For '4+ Goals', we need to include all goals from 4 to max_total_goals
        if end == max_total_goals:
            prob = np.sum(total_goals_probs[start:])
        else:
            prob = np.sum(total_goals_probs[start:end + 1])
        goal_range_probs[range_name] = prob

    # Display goal range probabilities and odds
    #print("\nGoal Range Probabilities and Odds:")
    for range_name, prob in goal_range_probs.items():
        odds = 1 / (prob + 1e-8)  # To prevent division by zero
        #print(f"{range_name}: Probability = {prob:.4f}, Odds = {odds:.2f}")

    # Calculate Odds
    def calculate_odds(prob):
        epsilon = 1e-8  # To prevent division by zero
        return 1 / (prob + epsilon)

    # Match outcome odds
    home_win_odds = calculate_odds(home_win_prob)
    draw_odds = calculate_odds(draw_prob)
    away_win_odds = calculate_odds(away_win_prob)

    # print("\nMatch Outcome Odds (Decimal):")
    # print(f"Home Win: {home_win_odds:.2f}")
    # print(f"Draw: {draw_odds:.2f}")
    # print(f"Away Win: {away_win_odds:.2f}")

    # Over/Under odds for total goals
    #print("\nOver/Under Total Goals Odds (Decimal):")
    for threshold in total_thresholds:
        under_odds = calculate_odds(over_under_total_results[threshold]['Under'])
        over_odds = calculate_odds(over_under_total_results[threshold]['Over'])
        #print(f"Under {threshold} total goals: {under_odds:.2f}, Over {threshold} total goals: {over_odds:.2f}")

    # Over/Under odds for individual team goals
    #print("\nOver/Under Goals Odds per Team (Decimal):")
    for team in [home_team, away_team]:
        #print(f"\n{team}:")
        for threshold in team_thresholds:
            under_prob = over_under_team_results[team][threshold]['Under']
            over_prob = over_under_team_results[team][threshold]['Over']
            under_odds = calculate_odds(under_prob)
            over_odds = calculate_odds(over_prob)
            #print(f"  Under {threshold} goals: {under_odds:.2f}, Over {threshold} goals: {over_odds:.2f}")

    # Add p_both_score to the return statement
    
    
    
    return home_win_prob, draw_prob, away_win_prob, over_under_total_results, over_under_team_results, goal_range_probs, p_both_score

# %%
def evaluate_btts(matches_df, params, thresholds):
    # Initialize a dictionary to store results for each threshold
    results = {threshold: {'correct_predictions': 0, 'total_predictions': 0} for threshold in thresholds}
    
    for index, row in matches_df.iterrows():
        home_team = row['homeTeam']
        away_team = row['awayTeam']
        actual_home_goals = row['homeScore']
        actual_away_goals = row['awayScore']
        
        # Get predicted probabilities
        # Use the existing predict function and extract p_both_score
        try:
            _, _, _, _, _, _, p_both_score = predict(params, home_team, away_team)
        except KeyError as e:
            print(f"Team {e} not found in parameters. Skipping this match.")
            continue

        # Iterate over each confidence threshold
        for threshold in thresholds:
            if p_both_score <= threshold:
                results[threshold]['total_predictions'] += 1
                predicted_outcome = 'Yes'  # Predicted BTTS to happen

                # Determine actual outcome
                actual_outcome = 'Yes' if (actual_home_goals > 0 and actual_away_goals > 0) else 'No'

                # Check if prediction is correct
                if predicted_outcome == actual_outcome:
                    results[threshold]['correct_predictions'] += 1

    # Calculate and print results for each threshold
    for threshold in thresholds:
        total = results[threshold]['total_predictions']
        correct = results[threshold]['correct_predictions']
        if total > 0:
            accuracy = correct / total
            print(f"\nConfidence Threshold >= {threshold}:")
            print(f"Total Predictions Made: {total}")
            print(f"Correct Predictions: {correct}")
            print(f"Accuracy: {accuracy:.2%}")
        else:
            print(f"\nConfidence Threshold >= {threshold}: No predictions made.")

    return results

# %%
confidence_thresholds = [0.9]
results = evaluate_btts(test, params, confidence_thresholds)

# %%
import numpy as np
import pandas as pd

def evaluate_model_with_combined_draw(matches_df, params, confidence_threshold=0.5):
    correct_predictions = 0
    total_matches = 0  # Count of matches considered with confidence above the threshold
    threshold_hits = 0  # Count of times the confidence threshold was met
    
    # For Log Loss
    log_loss = 0
    epsilon = 1e-15  # To prevent log(0)
    
    home_hits = 0
    away_hits = 0
    draw_hits = 0
    
    for index, row in matches_df.iterrows():
        home_team = row['homeTeam']
        away_team = row['awayTeam']
        actual_home_shots = row['homeScore']
        actual_away_shots = row['awayScore']
        
        # Get predicted probabilities
        home_prob, draw_prob, away_prob, _, _, _,_ = predict(params, home_team, away_team)
        
        # Determine max probability and combine it with draw if it's not already draw
        if home_prob > away_prob and home_prob > draw_prob:
            combined_prob = home_prob + draw_prob
            max_prob = combined_prob
            predicted_outcome = 'Home'
        elif away_prob > home_prob and away_prob > draw_prob:
            combined_prob = away_prob + draw_prob
            max_prob = combined_prob
            predicted_outcome = 'Away'
        else:
            max_prob = draw_prob
            predicted_outcome = 'Draw'
        
        # Only consider predictions with confidence above the threshold
        if max_prob >= confidence_threshold:
            threshold_hits += 1  # Increment the threshold hit count
            total_matches += 1
            
            # Determine actual outcome
            if actual_home_shots > actual_away_shots:
                actual_outcome = 'Home'
            elif actual_away_shots > actual_home_shots:
                actual_outcome = 'Away'
            else:
                actual_outcome = 'Draw'
            
            # Check if prediction is correct
            if predicted_outcome == actual_outcome:
                correct_predictions += 1
            
            # Update Log Loss based on the actual outcome
            if actual_outcome == 'Home':
                log_loss += -np.log(home_prob + epsilon)
                home_hits += 1
            elif actual_outcome == 'Draw':
                log_loss += -np.log(draw_prob + epsilon)
                draw_hits += 1
            else:
                log_loss += -np.log(away_prob + epsilon)
                away_hits += 1
    
    # Calculate Metrics
    if total_matches > 0:
        accuracy = correct_predictions / total_matches
        average_log_loss = log_loss / total_matches
        print(f"Accuracy (for confidence >= {confidence_threshold}): {accuracy:.2%}")
        print(f"Average Log Loss (for confidence >= {confidence_threshold}): {average_log_loss:.4f}")
    else:
        print(f"No predictions met the confidence threshold of {confidence_threshold}")
        accuracy = None
        average_log_loss = None
    
    print(f"Threshold hits (confidence >= {confidence_threshold}): {threshold_hits}")
    print(f"Home hits: {home_hits}, Away hits: {away_hits}, Draw hits: {draw_hits}")
    
    return accuracy, average_log_loss, threshold_hits, home_hits, away_hits, draw_hits

# Example usage:
# matches_df = pd.read_csv('historical_matches.csv')  # Ensure your CSV has the required columns
# evaluate_model_with_combined_draw(matches_df, params, confidence_threshold=0.7)

# %%
evaluate_model_with_combined_draw(test, params, confidence_threshold=0.92)

# %%
# Assuming you have a DataFrame 'matches_df' with historical match data
# Columns: 'HomeTeam', 'AwayTeam', 'HomeShots', 'AwayShots'

def evaluate_model(matches_df, params):
    correct_predictions = 0
    total_matches = len(matches_df)
    
    # For Brier Score
    brier_home = []
    brier_draw = []
    brier_away = []
    
    # For Log Loss
    log_loss = 0
    epsilon = 1e-15  # To prevent log(0)
    
    for index, row in matches_df.iterrows():
        home_team = row['homeTeam']
        away_team = row['awayTeam']
        actual_home_shots = row['homeScore']
        actual_away_shots = row['awayScore']
        
        # Get predicted probabilities
        home_prob, draw_prob, away_prob ,_,_,_,_= predict(params, home_team, away_team)
        
        # Determine predicted outcome
        if home_prob > away_prob and home_prob > draw_prob:
            predicted_outcome = 'Home'
            print(home_prob)
        elif away_prob > home_prob and away_prob > draw_prob:
            predicted_outcome = 'Away'
            print(away_prob)
        else:
            
            predicted_outcome = 'Draw'
        
        # Determine actual outcome
        if actual_home_shots > actual_away_shots:
            actual_outcome = 'Home'
        elif actual_away_shots > actual_home_shots:
            actual_outcome = 'Away'
        else:
            actual_outcome = 'Draw'
        
        # Check if prediction is correct
        if predicted_outcome == actual_outcome:
            correct_predictions += 1
        
        
        # Update Log Loss
        if actual_outcome == 'Home':
            log_loss += -np.log(home_prob + epsilon)
        elif actual_outcome == 'Draw':
            log_loss += -np.log(draw_prob + epsilon)
        else:
            log_loss += -np.log(away_prob + epsilon)
    
    # Calculate Metrics
    accuracy = correct_predictions / total_matches
    average_log_loss = log_loss / total_matches
    
    print(f"Accuracy: {accuracy:.2%}")
    print(f"Average Log Loss: {average_log_loss:.4f}")
    
    return accuracy, average_log_loss

# Example usage:
# matches_df = pd.read_csv('historical_matches.csv')  # Ensure your CSV has the required columns
# evaluate_model(matches_df, params)

# %%
evaluate_model(test,params)

# %%
import json
from botasaurus.request import request, Request
from botasaurus_requests import response
DATE = '2024-11-10'  # You can change this as needed


# Initialize the Botasaurus session
@request(output=None, create_error_logs=False)
def _botasaurus_get(request: Request, url: str) -> response.Response:
    """SofaScore introduced some anti-scraping measures. Using Botasaurus gets around them."""
    if not isinstance(url, str):
        raise TypeError('`url` must be a string.')
    response = request.get(url)
    return response

# %%
def fetch_scheduled_events(date):
    url = f'https://www.sofascore.com/api/v1/sport/football/scheduled-events/{date}'
    response = _botasaurus_get(url)
    if response.status_code == 200:
        print(response.json())
        return response.json()
    else:
        print(f"Failed to fetch events for {date}")
        return None

scheduled_events = fetch_scheduled_events(DATE)

# %%
from datetime import datetime  # For working with dates and times
# Prepare a list to store event details
teams_list = []

if scheduled_events:
    events = scheduled_events.get('events', [])
    for event in events:
        unique_tournament = event.get('tournament', {}).get('uniqueTournament', {})
        unique_tournament_id = unique_tournament.get('id')
        unique_tournament_name = unique_tournament.get('name')
        if unique_tournament_id in LEAGUES.values():
            event_id = event.get('id')
            tournament_name = unique_tournament.get('name')
            home_team_name = event.get('homeTeam', {}).get('name')
            away_team_name = event.get('awayTeam', {}).get('name')
            start_timestamp = event.get("startTimestamp")
            home_score = event.get('homeScore', {}).get('display', 0)
            away_score = event.get('awayScore', {}).get('display', 0)
            
            if start_timestamp:
                match_datetime = datetime.fromtimestamp(start_timestamp)
                match_date = match_datetime.strftime("%Y-%m-%d")
                match_time = match_datetime.strftime("%H:%M:%S")
            else:
                match_date = None
                match_time = None

            if match_date == DATE:

                teams_list.append({
                    'eventId':event_id,
                    'home_team_name': home_team_name,
                    'away_team_name': away_team_name,
                    
                })
else:
    print("No events found.")

# %%
prediction_df = pd.DataFrame(teams_list)

# %%
predict(params, 'Real Sociedad','Barcelona')

# %%
prediction_df

# %%
import pandas as pd

# Assuming 'prediction_df' is your DataFrame with 'home_team_name' and 'away_team_name' columns
# Also, 'params' is your parameters dictionary required by the 'predict' function

# Create an empty list to store the results
results = []

# Iterate over each game in the prediction DataFrame
for idx, row in prediction_df.iterrows():
    event_id = row['eventId']
    home_team = row['home_team_name']
    away_team = row['away_team_name']
    
    # Call your predict function
    (home_win_prob, draw_prob, away_win_prob,
     over_under_total_results, over_under_team_results,
     goal_range_probs, p_both_score) = predict(params, home_team, away_team)
    
    # Prepare a dictionary to store the results
    result = {
        'eventId': event_id,
        'home_team_name': home_team,
        'away_team_name': away_team,
        'home_win_prob': home_win_prob,
        'draw_prob': draw_prob,
        'away_win_prob': away_win_prob,
        'p_both_score': p_both_score
    }
    
    # Add Over/Under probabilities for the thresholds
    thresholds = [1.5, 2.5, 3.5]
    for threshold in thresholds:
        under_prob = over_under_total_results[threshold]['Under']
        over_prob = over_under_total_results[threshold]['Over']
        result[f'U{threshold}'] = under_prob
        result[f'O{threshold}'] = over_prob
    
    # Append the result to the list
    results.append(result)

# Create a new DataFrame from the results
new_prediction_df = pd.DataFrame(results)

# Display the new DataFrame
print(new_prediction_df)

# %%
new_prediction_df

# %%
# Calculate the maximum win probability and corresponding outcome for each match
def get_winner(row):
    probs = {
        'Home Win': row['home_win_prob'],
        'Draw': row['draw_prob'],
        'Away Win': row['away_win_prob']
    }
    # Find the outcome with the highest probability
    winner_outcome = max(probs, key=probs.get)
    winner_prob = probs[winner_outcome]
    return pd.Series([winner_outcome, winner_prob], index=['winner_outcome', 'winner_prob'])

# Apply the function to each row
new_prediction_df[['winner_outcome', 'winner_prob']] = new_prediction_df.apply(get_winner, axis=1)

# Create DataFrame sorted by winner probability
df_sorted_by_winner = new_prediction_df.sort_values(by='winner_prob', ascending=False)

# Create DataFrame sorted by Over 2.5 probability
df_sorted_by_over25 = new_prediction_df.sort_values(by='O2.5', ascending=False)

# Create DataFrame sorted by Under 2.5 probability
df_sorted_by_under25 = new_prediction_df.sort_values(by='U2.5', ascending=False)

df_sorted_btts = new_prediction_df.sort_values(by='p_both_score', ascending=False)

# %%
predict(params,"Liverpool","Aston Villa")

# %%
df_sorted_by_winner

# %%
df_sorted_by_over25

# %%
df_sorted_by_under25

# %%
df_sorted_btts

# %%
import pandas as pd
import time
import logging
from datetime import datetime
from tqdm import tqdm
import os
import json
from botasaurus.request import request, Request
from botasaurus_requests import response
import ScraperFC as sfc


ss = sfc.Sofascore()

DATE = '2024-11-09'  # You can change this as needed


# Initialize the Botasaurus session
@request(output=None, create_error_logs=False)
def _botasaurus_get(request: Request, url: str) -> response.Response:
    """SofaScore introduced some anti-scraping measures. Using Botasaurus gets around them."""
    if not isinstance(url, str):
        raise TypeError('`url` must be a string.')
    response = request.get(url)
    return response


def fetch_scheduled_events(date):
    url = f'https://www.sofascore.com/api/v1/sport/football/scheduled-events/{date}'
    response = _botasaurus_get(url)
    if response.status_code == 200:
        print(response.json())
        return response.json()
    else:
        print(f"Failed to fetch events for {date}")
        return None

scheduled_events = fetch_scheduled_events(DATE)


def filter_events_by_leagues(scheduled_events, leagues):
    """
    Filters events to only include those whose uniqueTournament ID is in the LEAGUES dictionary.

    Parameters:
    ----------
    scheduled_events : dict
        The dictionary containing all scheduled events.
    
    leagues : dict
        A dictionary of league names and their corresponding uniqueTournament IDs.
    
    Returns:
    -------
    list
        A filtered list of events.
    """
    all_events = scheduled_events.get('events', [])
    filtered_events = []

    for event in all_events:
        unique_tournament = event.get('tournament', {}).get('uniqueTournament', {})
        unique_tournament_id = unique_tournament.get('id')
        
        if unique_tournament_id in leagues.values():
            filtered_events.append(event)

    return filtered_events



def process_and_append_events(scheduled_events, csv_filename='europa_data_final.csv'):
    matches_data = []
    todays_games = []  # List to store today's games for comparison
    
    for event in tqdm(scheduled_events, desc="Processing events", unit="event"):
        try:
            event_id = event.get("id", None)
            home_team = event.get('homeTeam', {}).get('name', 'Unknown')
            home_team_id = event.get('homeTeam', {}).get('id', 'Unknown')
            away_team = event.get('awayTeam', {}).get('name', 'Unknown')
            away_team_id = event.get('awayTeam', {}).get('id', 'Unknown')
            home_score = event.get('homeScore', {}).get('display', 0)
            away_score = event.get('awayScore', {}).get('display', 0)

            start_timestamp = event.get("startTimestamp")
            if start_timestamp:
                match_datetime = datetime.fromtimestamp(start_timestamp)
                match_date = match_datetime.strftime("%Y-%m-%d")
                match_time = match_datetime.strftime("%H:%M:%S")
            else:
                match_date = None
                match_time = None

            gd = home_score - away_score
            if gd == 0:
                FTR = 1
            elif gd > 0:
                FTR = 0
            else:
                FTR = 2

            # Simulating match data scraping (replace this with the actual function call)
            match_data = ss.scrape_team_match_stats(event_id)
            match_data_filtered = match_data[['key', 'home', 'away']]

            new_row = {
                "eventId": event_id,
                "homeId": home_team_id,
                "homeTeam": home_team,
                "awayId": away_team_id,
                "awayTeam": away_team,
                "homeScore": home_score,
                "awayScore": away_score,
                "FTR": FTR,
                "date": match_date,
                "time": match_time
            }

            for index, row in match_data_filtered.iterrows():
                key = row['key']
                new_row[f'home{key}'] = row['home']
                new_row[f'away{key}'] = row['away']

            # Store today's games for comparison
            if match_date == DATE:
                todays_games.append(new_row)

            # Append data to CSV
            df = pd.DataFrame([new_row])
            if os.path.exists(csv_filename):
                df.to_csv(csv_filename, mode='a', index=False, header=False)
            else:
                df.to_csv(csv_filename, mode='w', index=False, header=True)

        except Exception as e:
            logging.error(f"Error processing event {event.get('id', 'Unknown')}: {e}", exc_info=True)
            continue  # Skip to the next event in case of an error

        time.sleep(1)

    # Create DataFrame of today's games
    todays_df = pd.DataFrame(todays_games)
    return todays_df


# Usage example
if scheduled_events:
    filtered_events = filter_events_by_leagues(scheduled_events, LEAGUES)
    todays_games_df = process_and_append_events(filtered_events)  # Collect today's games
    print("Today's games for comparison:")
else:
    print("No events available to process.")

    
# Fetch scheduled events
scheduled_events = fetch_scheduled_events(DATE)

if scheduled_events:
    filtered_events = filter_events_by_leagues(scheduled_events, LEAGUES)
    process_and_append_events(filtered_events)  # Pass the filtered events to your function
else:
    print("No events available to process.")

# %%
todays_games_df

# %%
def evaluate_predictions(predictions_df, actuals_df):
    """
    Evaluates the prediction accuracy for full-time results, thresholds (O/U), and BTTS.
    
    Parameters:
    ----------
    predictions_df : pd.DataFrame
        DataFrame containing prediction probabilities for each match, including `eventId`.
    
    actuals_df : pd.DataFrame
        DataFrame containing actual match outcomes, including `eventId`.
    
    Returns:
    -------
    dict
        Evaluation results for full-time result accuracy, thresholds (O/U), and BTTS.
    """
    correct_results = 0
    total_predictions = len(predictions_df)
    
    over_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    over_count = {1.5: 0, 2.5: 0, 3.5: 0}
    
    under_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    under_count = {1.5: 0, 2.5: 0, 3.5: 0}
    
    btts_hits = 0
    btts_count = 0
    unmatched_predictions = 0

    for idx, row in predictions_df.iterrows():
        event_id = row['eventId']
        
        # Find corresponding actual match
        actual_match = actuals_df[actuals_df['eventId'] == event_id]

        if actual_match.empty:
            unmatched_predictions += 1
            logging.warning(f"No actual data found for eventId {event_id}. Skipping.")
            continue
        
        actual_match = actual_match.iloc[0]
        
        actual_home_score = actual_match['homeScore']
        actual_away_score = actual_match['awayScore']
        
        # Determine actual full-time result (0: Home Win, 1: Draw, 2: Away Win)
        actual_result = 1  # Default to Draw
        if actual_home_score > actual_away_score:
            actual_result = 0  # Home Win
        elif actual_home_score < actual_away_score:
            actual_result = 2  # Away Win
        
        # Determine predicted full-time result
        predicted_result = max(
            ['home_win_prob', 'draw_prob', 'away_win_prob'],
            key=lambda x: row[x]
        )
        result_mapping = {'home_win_prob': 0, 'draw_prob': 1, 'away_win_prob': 2}
        predicted_result = result_mapping[predicted_result]
        
        # Correct if predicted result matches actual result or it's a draw
        if predicted_result == actual_result or actual_result == 1:
            correct_results += 1
        
        # Check BTTS
        actual_btts = (actual_home_score > 0) and (actual_away_score > 0)
        if row['p_both_score'] > 0.5:
            btts_count += 1
            if actual_btts:
                btts_hits += 1
        
        # Check thresholds (O/U)
        total_goals = actual_home_score + actual_away_score
        thresholds = [1.5, 2.5, 3.5]
        for threshold in thresholds:
            if row[f'O{threshold}'] > 0.5:
                over_count[threshold] += 1
                if total_goals > threshold:
                    over_hits[threshold] += 1
            if row[f'U{threshold}'] > 0.5:
                under_count[threshold] += 1
                if total_goals <= threshold:
                    under_hits[threshold] += 1

    # Calculate percentages and counts
    result_accuracy = {
        'correct': correct_results,
        'total': total_predictions - unmatched_predictions,
        'accuracy': correct_results / (total_predictions - unmatched_predictions) * 100
    }
    
    btts_accuracy = {
        'correct': btts_hits,
        'total': btts_count,
        'accuracy': btts_hits / btts_count * 100 if btts_count > 0 else 0
    }
    
    over_accuracy = {
        threshold: {
            'correct': over_hits[threshold],
            'total': over_count[threshold],
            'accuracy': (over_hits[threshold] / over_count[threshold] * 100 
                         if over_count[threshold] > 0 else 0)
        }
        for threshold in thresholds
    }
    
    under_accuracy = {
        threshold: {
            'correct': under_hits[threshold],
            'total': under_count[threshold],
            'accuracy': (under_hits[threshold] / under_count[threshold] * 100 
                         if under_count[threshold] > 0 else 0)
        }
        for threshold in thresholds
    }

    return {
        'result_accuracy': result_accuracy,
        'btts_accuracy': btts_accuracy,
        'over_accuracy': over_accuracy,
        'under_accuracy': under_accuracy,
        'unmatched_predictions': unmatched_predictions
    }

# %%
evaluation_results = evaluate_predictions(new_prediction_df, todays_games_df)

print("Full-Time Result Accuracy:", evaluation_results['result_accuracy'], "%")
print("BTTS Accuracy:", evaluation_results['btts_accuracy'], "%")
print("Over Threshold Accuracy:", evaluation_results['over_accuracy'])
print("Under Threshold Accuracy:", evaluation_results['under_accuracy'])
print("Unmatched Predictions:", evaluation_results['unmatched_predictions'])

# %%
def evaluate_predictions(predictions_df, actuals_df, confidence_range=(0.6, 0.7)):
    """
    Evaluates the prediction accuracy for full-time results, thresholds (O/U), and BTTS
    within a specified confidence range.
    
    Parameters:
    ----------
    predictions_df : pd.DataFrame
        DataFrame containing prediction probabilities for each match, including `eventId`.
    
    actuals_df : pd.DataFrame
        DataFrame containing actual match outcomes, including `eventId`.
    
    confidence_range : tuple, optional
        Range of confidence levels to filter predictions for accuracy evaluation.
    
    Returns:
    -------
    dict
        Evaluation results for full-time result accuracy, thresholds (O/U), and BTTS within confidence interval.
    """
    lower_bound, upper_bound = confidence_range
    
    correct_results = 0
    total_predictions = len(predictions_df)
    
    over_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    over_count = {1.5: 0, 2.5: 0, 3.5: 0}
    
    under_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    under_count = {1.5: 0, 2.5: 0, 3.5: 0}
    
    btts_hits = 0
    btts_count = 0
    unmatched_predictions = 0

    # Confidence-range specific counters for all metrics
    confidence_result_hits = 0
    confidence_result_total = 0

    confidence_over_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    confidence_over_count = {1.5: 0, 2.5: 0, 3.5: 0}
    
    confidence_under_hits = {1.5: 0, 2.5: 0, 3.5: 0}
    confidence_under_count = {1.5: 0, 2.5: 0, 3.5: 0}

    confidence_btts_hits = 0
    confidence_btts_total = 0

    for idx, row in predictions_df.iterrows():
        event_id = row['eventId']
        
        # Find corresponding actual match
        actual_match = actuals_df[actuals_df['eventId'] == event_id]

        if actual_match.empty:
            unmatched_predictions += 1
            logging.warning(f"No actual data found for eventId {event_id}. Skipping.")
            continue
        
        actual_match = actual_match.iloc[0]
        
        actual_home_score = actual_match['homeScore']
        actual_away_score = actual_match['awayScore']
        
        # Determine actual full-time result (0: Home Win, 1: Draw, 2: Away Win)
        actual_result = 1  # Default to Draw
        if actual_home_score > actual_away_score:
            actual_result = 0  # Home Win
        elif actual_home_score < actual_away_score:
            actual_result = 2  # Away Win
        
        result_mapping = {
            'home_win_prob': 0,
            'draw_prob': 1,
            'away_win_prob': 2
        }
        predicted_result = max(
            ['home_win_prob', 'draw_prob', 'away_win_prob'],
            key=lambda x: row[x]
        )

        confidence = row[predicted_result]  # Use the correct string key to get the confidence


        # Evaluate full-time result within confidence range
        if lower_bound <= confidence <= upper_bound:
            confidence_result_total += 1
            if result_mapping[predicted_result] == actual_result or actual_result == 1:
                confidence_result_hits += 1
        
        if predicted_result == actual_result or actual_result == 1:
            correct_results += 1
        
        # Check BTTS
        actual_btts = (actual_home_score > 0) and (actual_away_score > 0)
        if row['p_both_score'] > 0.5:
            btts_count += 1
            if actual_btts:
                btts_hits += 1
            # Evaluate BTTS within confidence range
            if lower_bound <= row['p_both_score'] <= upper_bound:
                confidence_btts_total += 1
                if actual_btts:
                    confidence_btts_hits += 1
        
        # Check thresholds (O/U)
        total_goals = actual_home_score + actual_away_score
        thresholds = [1.5, 2.5, 3.5]
        for threshold in thresholds:
            if row[f'O{threshold}'] > 0.5:
                over_count[threshold] += 1
                if total_goals > threshold:
                    over_hits[threshold] += 1
                # Confidence check for Over
                if lower_bound <= row[f'O{threshold}'] <= upper_bound:
                    confidence_over_count[threshold] += 1
                    if total_goals > threshold:
                        confidence_over_hits[threshold] += 1
            
            if row[f'U{threshold}'] > 0.5:
                under_count[threshold] += 1
                if total_goals <= threshold:
                    under_hits[threshold] += 1
                # Confidence check for Under
                if lower_bound <= row[f'U{threshold}'] <= upper_bound:
                    confidence_under_count[threshold] += 1
                    if total_goals <= threshold:
                        confidence_under_hits[threshold] += 1

    result_accuracy = {
        'correct': correct_results,
        'total': total_predictions - unmatched_predictions,
        'accuracy': correct_results / (total_predictions - unmatched_predictions) * 100
    }
    
    btts_accuracy = {
        'correct': btts_hits,
        'total': btts_count,
        'accuracy': btts_hits / btts_count * 100 if btts_count > 0 else 0
    }
    
    over_accuracy = {
        threshold: {
            'correct': over_hits[threshold],
            'total': over_count[threshold],
            'accuracy': (over_hits[threshold] / over_count[threshold] * 100 
                         if over_count[threshold] > 0 else 0)
        }
        for threshold in thresholds
    }
    
    under_accuracy = {
        threshold: {
            'correct': under_hits[threshold],
            'total': under_count[threshold],
            'accuracy': (under_hits[threshold] / under_count[threshold] * 100 
                         if under_count[threshold] > 0 else 0)
        }
        for threshold in thresholds
    }

    confidence_accuracy = {
        'result_accuracy': {
            'correct': confidence_result_hits,
            'total': confidence_result_total,
            'accuracy': (confidence_result_hits / confidence_result_total * 100 if confidence_result_total > 0 else 0)
        },
        'btts_accuracy': {
            'correct': confidence_btts_hits,
            'total': confidence_btts_total,
            'accuracy': (confidence_btts_hits / confidence_btts_total * 100 if confidence_btts_total > 0 else 0)
        },
        'over_accuracy': {
            threshold: {
                'correct': confidence_over_hits[threshold],
                'total': confidence_over_count[threshold],
                'accuracy': (confidence_over_hits[threshold] / confidence_over_count[threshold] * 100 
                             if confidence_over_count[threshold] > 0 else 0)
            }
            for threshold in thresholds
        },
        'under_accuracy': {
            threshold: {
                'correct': confidence_under_hits[threshold],
                'total': confidence_under_count[threshold],
                'accuracy': (confidence_under_hits[threshold] / confidence_under_count[threshold] * 100 
                             if confidence_under_count[threshold] > 0 else 0)
            }
            for threshold in thresholds
        }
    }

    return {
        'result_accuracy': result_accuracy,
        'btts_accuracy': btts_accuracy,
        'over_accuracy': over_accuracy,
        'under_accuracy': under_accuracy,
        'confidence_accuracy': confidence_accuracy,
        'unmatched_predictions': unmatched_predictions
    }

# %%
evaluation_results = evaluate_predictions(new_prediction_df, todays_games_df, confidence_range=(0.6, 0.7))

print("Full-Time Result Accuracy:", evaluation_results['result_accuracy'])
print("BTTS Accuracy:", evaluation_results['btts_accuracy'])
print("Over Threshold Accuracy:", evaluation_results['over_accuracy'])
print("Under Threshold Accuracy:", evaluation_results['under_accuracy'])
print("Confidence Range Accuracy (60-70%):", evaluation_results['confidence_accuracy'])
print("Unmatched Predictions:", evaluation_results['unmatched_predictions'])

# %%
predict(params,"Chelsea","Arsenal")
